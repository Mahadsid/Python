# %%
import pandas as pd

# %%
df = pd.read_csv("developer_survey_2021/survey_results_public.csv")

# %%
df
# Out:
#        ResponseId                                         MainBranch  \
# 0               1                     I am a developer by profession
# 1               2             I am a student who is learning to code
# 2               3  I am not primarily a developer, but I write co...
# 3               4                     I am a developer by profession
# 4               5                     I am a developer by profession
# ...           ...                                                ...
# 83434       83435                     I am a developer by profession
# 83435       83436                     I am a developer by profession
# 83436       83437                     I am a developer by profession
# 83437       83438                     I am a developer by profession
# 83438       83439                     I am a developer by profession
#
#                                               Employment  \
# 0      Independent contractor, freelancer, or self-em...
# ...

# %%
df.shape
# Out:
# (83439, 48)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 83439 entries, 0 to 83438
# Data columns (total 48 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   ResponseId                    83439 non-null  int64
#  1   MainBranch                    83439 non-null  object
#  2   Employment                    83323 non-null  object
#  3   Country                       83439 non-null  object
#  4   US_State                      14920 non-null  object
#  5   UK_Country                    4418 non-null   object
#  6   EdLevel                       83126 non-null  object
#  7   Age1stCode                    83243 non-null  object
#  8   LearnCode                     82963 non-null  object
#  9   YearsCode                     81641 non-null  object
#  10  YearsCodePro                  61216 non-null  object
#  11  DevType                       66484 non-null  object
# ...

# %%
pd.set_option('display.max_columns',48)

# %%
df
# Out:
#        ResponseId                                         MainBranch  \
# 0               1                     I am a developer by profession
# 1               2             I am a student who is learning to code
# 2               3  I am not primarily a developer, but I write co...
# 3               4                     I am a developer by profession
# 4               5                     I am a developer by profession
# ...           ...                                                ...
# 83434       83435                     I am a developer by profession
# 83435       83436                     I am a developer by profession
# 83436       83437                     I am a developer by profession
# 83437       83438                     I am a developer by profession
# 83438       83439                     I am a developer by profession
#
#                                               Employment  \
# 0      Independent contractor, freelancer, or self-em...
# ...

# %%
schema_df = pd.read_csv('developer_survey_2021/survey_results_schema.csv') # gives columns schema of data set

# %%
schema_df
# Out:
#        qid               qname  \
# 0    QID16                  S0
# 1    QID12            MetaInfo
# 2     QID1                  S1
# 3     QID2          MainBranch
# 4    QID24          Employment
# 5     QID6             Country
# 6     QID7            US_State
# 7     QID9          UK_Country
# 8   QID190                  S2
# 9    QID25             EdLevel
# 10  QID149          Age1stCode
# 11  QID276           LearnCode
# 12   QID32           YearsCode
# 13   QID34        YearsCodePro
# 14   QID31             DevType
# 15   QID29             OrgSize
# 16   QID50            Currency
# 17   QID51           CompTotal
# 18   QID52            CompFreq
# 19   QID61                  S3
# 20  QID233            Language
# 21  QID262            Database
# 22  QID263            Platform
# 23  QID264            Webframe
# 24  QID265            MiscTech
# 25  QID275           ToolsTech
# 26  QID274      NEWCollabTools
# 27   QID71               OpSys
# 28  QID243            NEWStuck
# ...

# %%
#if large data and schema is not fully visible: pd.set_option('display.max_rows',48)

# %%
df.head(10)
# Out:
#    ResponseId                                         MainBranch  \
# 0           1                     I am a developer by profession
# 1           2             I am a student who is learning to code
# 2           3  I am not primarily a developer, but I write co...
# 3           4                     I am a developer by profession
# 4           5                     I am a developer by profession
# 5           6             I am a student who is learning to code
# 6           7                        I code primarily as a hobby
# 7           8             I am a student who is learning to code
# 8           9                     I am a developer by profession
# 9          10                     I am a developer by profession
#
#                                           Employment  \
# 0  Independent contractor, freelancer, or self-em...
# 1                                 Student, full-time
# 2                                 Student, full-time
# ...

# %%
df.tail(5)
# Out:
#        ResponseId                      MainBranch  \
# 83434       83435  I am a developer by profession
# 83435       83436  I am a developer by profession
# 83436       83437  I am a developer by profession
# 83437       83438  I am a developer by profession
# 83438       83439  I am a developer by profession
#
#                                               Employment  \
# 83434                                 Employed full-time
# 83435  Independent contractor, freelancer, or self-em...
# 83436                                 Employed full-time
# 83437                                 Employed full-time
# 83438                                 Employed full-time
#
#                         Country    US_State UK_Country  \
# 83434  United States of America       Texas        NaN
# 83435                     Benin         NaN        NaN
# 83436  United States of America  New Jersey        NaN
# 83437                    Canada         NaN        NaN
# ...

# %% [markdown]
# # DataFrames & Series datatypes

# %%
# let us first create a python dictionary to better understand this in easy way
people = {
    "first" : ["Muhammad","Mike", "Me"], # using list in value pair bcaz we can store multiple elements
    "last" : ["Ali","Tyson","Podcast"],
    "email" : ["muhammadali786@gmail.com","miketyson10@gmail.com","mygmail1245@yahoo.com"]

}

# %%
# now creating DataFrame of dictionary
df1 = pd.DataFrame(people)

# %%
df1
# Out:
#       first     last                     email
# 0  Muhammad      Ali  muhammadali786@gmail.com
# 1      Mike    Tyson     miketyson10@gmail.com
# 2        Me  Podcast     mygmail1245@yahoo.com

# %%
# accessing single column
print(df1['email'])
print(type(df1['email']))
# Out:
# 0    muhammadali786@gmail.com
# 1       miketyson10@gmail.com
# 2       mygmail1245@yahoo.com
# Name: email, dtype: object
# <class 'pandas.core.series.Series'>

# %%
df1.head(1) # can use -ve indecies as well
# Out:
#       first last                     email
# 0  Muhammad  Ali  muhammadali786@gmail.com

# %%
df1.tail(1)
# Out:
#   first     last                  email
# 2    Me  Podcast  mygmail1245@yahoo.com

# %%
df1[['last', 'email']] #, getting multiple columns with their value, here we are passing list, use syntax correctly,
# Out:
#       last                     email
# 0      Ali  muhammadali786@gmail.com
# 1    Tyson     miketyson10@gmail.com
# 2  Podcast     mygmail1245@yahoo.com

# %%
# to know all columns name
df1.columns
# Out:
# Index(['first', 'last', 'email'], dtype='object')

# %%
# to get row : 1)loc 2)iloc
# iloc or integer location: so pass intefers only
df1.iloc[0] # first row           


# remember all columns and row indexes start with 0
# Out:
# first                    Muhammad
# last                          Ali
# email    muhammadali786@gmail.com
# Name: 0, dtype: object

# %%
# first and second row
df1.iloc[[0, 1]]
# Out:
#       first   last                     email
# 0  Muhammad    Ali  muhammadali786@gmail.com
# 1      Mike  Tyson     miketyson10@gmail.com

# %%
#rows and columns by iloc :syntax df.[[rows],[columns]]
df1.iloc[[0,1],2] # we get email column for those two rows
# Out:
# 0    muhammadali786@gmail.com
# 1       miketyson10@gmail.com
# Name: email, dtype: object

# %%
df1.iloc[[0,1],[1,2]] # we get second(i.e 1) and third (i.e. 2) COLUMN, for first (i.e. 0) and second (i.e 1) ROW
# Out:
#     last                     email
# 0    Ali  muhammadali786@gmail.com
# 1  Tyson     miketyson10@gmail.com

# %%
# loc searching by labels
df1.loc[1]
# Out:
# first                     Mike
# last                     Tyson
# email    miketyson10@gmail.com
# Name: 1, dtype: object

# %%
df1.loc[[1,2]]
# Out:
#   first     last                  email
# 1  Mike    Tyson  miketyson10@gmail.com
# 2    Me  Podcast  mygmail1245@yahoo.com

# %%
df1.loc[[1,2], 'email']
# Out:
# 1    miketyson10@gmail.com
# 2    mygmail1245@yahoo.com
# Name: email, dtype: object

# %%
df1.loc[[1,2], ['email', 'last']]
# Out:
#                    email     last
# 1  miketyson10@gmail.com    Tyson
# 2  mygmail1245@yahoo.com  Podcast

# %% [markdown]
# ### back to our main dataframe !!

# %%
df.shape
# Out:
# (83439, 48)

# %%
#lets grab specific columns
df.columns
# Out:
# Index(['ResponseId', 'MainBranch', 'Employment', 'Country', 'US_State',
#        'UK_Country', 'EdLevel', 'Age1stCode', 'LearnCode', 'YearsCode',
#        'YearsCodePro', 'DevType', 'OrgSize', 'Currency', 'CompTotal',
#        'CompFreq', 'LanguageHaveWorkedWith', 'LanguageWantToWorkWith',
#        'DatabaseHaveWorkedWith', 'DatabaseWantToWorkWith',
#        'PlatformHaveWorkedWith', 'PlatformWantToWorkWith',
#        'WebframeHaveWorkedWith', 'WebframeWantToWorkWith',
#        'MiscTechHaveWorkedWith', 'MiscTechWantToWorkWith',
#        'ToolsTechHaveWorkedWith', 'ToolsTechWantToWorkWith',
#        'NEWCollabToolsHaveWorkedWith', 'NEWCollabToolsWantToWorkWith', 'OpSys',
#        'NEWStuck', 'NEWSOSites', 'SOVisitFreq', 'SOAccount', 'SOPartFreq',
#        'SOComm', 'NEWOtherComms', 'Age', 'Gender', 'Trans', 'Sexuality',
#        'Ethnicity', 'Accessibility', 'MentalHealth', 'SurveyLength',
#        'SurveyEase', 'ConvertedCompYearly'],
#       dtype='object')

# %%
# Lets grab country column
df['Country']
# Out:
# 0                                                 Slovakia
# 1                                              Netherlands
# 2                                       Russian Federation
# 3                                                  Austria
# 4        United Kingdom of Great Britain and Northern I...
#                                ...
# 83434                             United States of America
# 83435                                                Benin
# 83436                             United States of America
# 83437                                               Canada
# 83438                                               Brazil
# Name: Country, Length: 83439, dtype: object

# %%
# now let grab gender column
df['Gender']
# Out:
# 0        Man
# 1        Man
# 2        Man
# 3        Man
# 4        Man
#         ...
# 83434    Man
# 83435    Man
# 83436    Man
# 83437    Man
# 83438    Man
# Name: Gender, Length: 83439, dtype: object

# %%
# we can see how many are answered man, and how many answer in woman and in others
df['Gender'].value_counts()
# Out:
# Man                                                                                   74817
# Woman                                                                                  4120
# Prefer not to say                                                                      1442
# Non-binary, genderqueer, or gender non-conforming                                       690
# Or, in your own words:                                                                  413
# Man;Or, in your own words:                                                              268
# Man;Non-binary, genderqueer, or gender non-conforming                                   252
# Woman;Non-binary, genderqueer, or gender non-conforming                                 147
# Man;Woman                                                                                41
# Non-binary, genderqueer, or gender non-conforming;Or, in your own words:                 21
# ...

# %%
# lets get specific row 
df.loc[0] # these were the values of row 1, with each column accordingly
# Out:
# ResponseId                                                                      1
# MainBranch                                         I am a developer by profession
# Employment                      Independent contractor, freelancer, or self-em...
# Country                                                                  Slovakia
# US_State                                                                      NaN
# UK_Country                                                                    NaN
# EdLevel                         Secondary school (e.g. American high school, G...
# Age1stCode                                                          18 - 24 years
# LearnCode                       Coding Bootcamp;Other online resources (ex: vi...
# YearsCode                                                                     NaN
# YearsCodePro                                                                  NaN
# ...

# %%
# we can get specific row value, associated with specific column
df.loc[0,'Country']
# Out:
# 'Slovakia'

# %%
# can pass multiple columns and rows 
df.loc[[0,1,2],['MainBranch','Country', 'Gender','Age']]
# Out:
#                                           MainBranch             Country  \
# 0                     I am a developer by profession            Slovakia
# 1             I am a student who is learning to code         Netherlands
# 2  I am not primarily a developer, but I write co...  Russian Federation
#
#   Gender              Age
# 0    Man  25-34 years old
# 1    Man  18-24 years old
# 2    Man  18-24 years old

# %%
# using slicing technique
df.loc[0 : 6,['MainBranch','Country', 'Gender','Age']] # on slicing dont use brackets,
# here last vlaue is enclusive, not like exclusice in list
# Out:
#                                           MainBranch  \
# 0                     I am a developer by profession
# 1             I am a student who is learning to code
# 2  I am not primarily a developer, but I write co...
# 3                     I am a developer by profession
# 4                     I am a developer by profession
# 5             I am a student who is learning to code
# 6                        I code primarily as a hobby
#
#                                              Country             Gender  \
# 0                                           Slovakia                Man
# 1                                        Netherlands                Man
# 2                                 Russian Federation                Man
# 3                                            Austria                Man
# 4  United Kingdom of Great Britain and Northern I...                Man
# 5                           United States of America  Prefer not to say
# ...

# %%
# also using slicing technique in columns
df.loc[0 : 6,'MainBranch' : 'US_State'] # here last vlaue in enclusive, not like exclusice in list
# Out:
#                                           MainBranch  \
# 0                     I am a developer by profession
# 1             I am a student who is learning to code
# 2  I am not primarily a developer, but I write co...
# 3                     I am a developer by profession
# 4                     I am a developer by profession
# 5             I am a student who is learning to code
# 6                        I code primarily as a hobby
#
#                                           Employment  \
# 0  Independent contractor, freelancer, or self-em...
# 1                                 Student, full-time
# 2                                 Student, full-time
# 3                                 Employed full-time
# 4  Independent contractor, freelancer, or self-em...
# 5                                 Student, part-time
# 6                                I prefer not to say
#
#                                              Country       US_State
# ...

# %% [markdown]
# # Indexes : How to set, reset, and use indexes

# %%
# now lests jump back to our practice dataframe to see how to set other column as an index
df1
# Out:
#       first     last                     email
# 0  Muhammad      Ali  muhammadali786@gmail.com
# 1      Mike    Tyson     miketyson10@gmail.com
# 2        Me  Podcast     mygmail1245@yahoo.com

# %% [markdown]
# ### set our index

# %%
df1.set_index('email') # see email column as darkened
# Out:
#                              first     last
# email
# muhammadali786@gmail.com  Muhammad      Ali
# miketyson10@gmail.com         Mike    Tyson
# mygmail1245@yahoo.com           Me  Podcast

# %%
# but our dataframe is not changed look, its good that it dos'nt change unless we do it
df1
# Out:
#       first     last                     email
# 0  Muhammad      Ali  muhammadali786@gmail.com
# 1      Mike    Tyson     miketyson10@gmail.com
# 2        Me  Podcast     mygmail1245@yahoo.com

# %%
# lets do chnage it for real
df1.set_index('email', inplace=True) # now email is set as index in our original dataframe
df1
# Out:
#                              first     last
# email
# muhammadali786@gmail.com  Muhammad      Ali
# miketyson10@gmail.com         Mike    Tyson
# mygmail1245@yahoo.com           Me  Podcast

# %%
# index gives us a unique identifier for our rows
df1.index
# Out:
# Index(['muhammadali786@gmail.com', 'miketyson10@gmail.com',
#        'mygmail1245@yahoo.com'],
#       dtype='object', name='email')

# %%
df1.loc['muhammadali786@gmail.com'] # before we are passing integer in loc bcz our indexes are int, now we can pass labels bcz we changed our index to a label
# Out:
# first    Muhammad
# last          Ali
# Name: muhammadali786@gmail.com, dtype: object

# %%
df1.loc['muhammadali786@gmail.com','first'] # now we can use it to access different columns
# Out:
# 'Muhammad'

# %%
# now if we use df1.loc[0] it give error
# but if we use :
df1.iloc[0] # it works fine bcz its integer loc
# Out:
# first    Muhammad
# last          Ali
# Name: muhammadali786@gmail.com, dtype: object

# %% [markdown]
# ### now lets reset our index

# %%
df1.reset_index(inplace=True)
df1
# Out:
#                       email     first     last
# 0  muhammadali786@gmail.com  Muhammad      Ali
# 1     miketyson10@gmail.com      Mike    Tyson
# 2     mygmail1245@yahoo.com        Me  Podcast

# %% [markdown]
# # In our main DataFrame lets set our index other from default

# %%
df.head(5)
# Out:
#    ResponseId                                         MainBranch  \
# 0           1                     I am a developer by profession
# 1           2             I am a student who is learning to code
# 2           3  I am not primarily a developer, but I write co...
# 3           4                     I am a developer by profession
# 4           5                     I am a developer by profession
#
#                                           Employment  \
# 0  Independent contractor, freelancer, or self-em...
# 1                                 Student, full-time
# 2                                 Student, full-time
# 3                                 Employed full-time
# 4  Independent contractor, freelancer, or self-em...
#
#                                              Country US_State UK_Country  \
# 0                                           Slovakia      NaN        NaN
# 1                                        Netherlands      NaN        NaN
# ...

# %%
# since we are seeing ResponseId is one unique column that represent every row uniquely so lets set it as our index
df.set_index('ResponseId') # note that i am not reflecting that it in original dataframe


# WE can set our index at the time of loading csv, which is more prefrable: syntax: (but we have to know that specific column that uniquely identify each row in advance)
# df = pd.read_csv("folder/survey_results_public.csv", index_col='ResponseId')
# Out:
#                                                    MainBranch  \
# ResponseId
# 1                              I am a developer by profession
# 2                      I am a student who is learning to code
# 3           I am not primarily a developer, but I write co...
# 4                              I am a developer by profession
# 5                              I am a developer by profession
# ...                                                       ...
# 83435                          I am a developer by profession
# 83436                          I am a developer by profession
# 83437                          I am a developer by profession
# 83438                          I am a developer by profession
# 83439                          I am a developer by profession
#
#                                                    Employment  \
# ResponseId
# 1           Independent contractor, freelancer, or self-em...
# 2                                          Student, full-time
# ...

# %%
df.head(5) # see its not reflect it our main dataframe
# Out:
#    ResponseId                                         MainBranch  \
# 0           1                     I am a developer by profession
# 1           2             I am a student who is learning to code
# 2           3  I am not primarily a developer, but I write co...
# 3           4                     I am a developer by profession
# 4           5                     I am a developer by profession
#
#                                           Employment  \
# 0  Independent contractor, freelancer, or self-em...
# 1                                 Student, full-time
# 2                                 Student, full-time
# 3                                 Employed full-time
# 4  Independent contractor, freelancer, or self-em...
#
#                                              Country US_State UK_Country  \
# 0                                           Slovakia      NaN        NaN
# 1                                        Netherlands      NaN        NaN
# ...

# %% [markdown]
# ## So where do we use it!<br>
# #### since we know that schema dataframe, so we can make columns as our index and can know what that represent ! lets take a look

# %%
schema_df.head(10)
# Out:
#       qid       qname                                           question  \
# 0   QID16          S0  <div><span style="font-size:19px;"><strong>Hel...
# 1   QID12    MetaInfo                                  Browser Meta Info
# 2    QID1          S1  <span style="font-size:22px; font-family: aria...
# 3    QID2  MainBranch  Which of the following options best describes ...
# 4   QID24  Employment  Which of the following best describes your cur...
# 5    QID6     Country  Where do you live? <span style="font-weight: b...
# 6    QID7    US_State  <p>In which state or territory of the USA do y...
# 7    QID9  UK_Country  In which part of the United Kingdom do you liv...
# 8  QID190          S2  <span style="font-size:22px; font-family: aria...
# 9   QID25     EdLevel  Which of the following best describes the high...
#
#    force_resp  type selector
# 0       False    DB       TB
# 1       False  Meta  Browser
# 2       False    DB       TB
# 3        True    MC     SAVR
# ...

# %%
schema_df.set_index('qname',inplace=True)

# %%
schema_df
# Out:
#                        qid                                           question  \
# qname
# S0                   QID16  <div><span style="font-size:19px;"><strong>Hel...
# MetaInfo             QID12                                  Browser Meta Info
# S1                    QID1  <span style="font-size:22px; font-family: aria...
# MainBranch            QID2  Which of the following options best describes ...
# Employment           QID24  Which of the following best describes your cur...
# Country               QID6  Where do you live? <span style="font-weight: b...
# US_State              QID7  <p>In which state or territory of the USA do y...
# UK_Country            QID9  In which part of the United Kingdom do you liv...
# S2                  QID190  <span style="font-size:22px; font-family: aria...
# EdLevel              QID25  Which of the following best describes the high...
# Age1stCode          QID149  At what age did you write your first line of c...
# ...

# %%
schema_df.loc['Age']
# Out:
# qid                      QID127
# question      What is your age?
# force_resp                False
# type                         MC
# selector                   MAVR
# Name: Age, dtype: object

# %%
schema_df.loc['Language','question'] # now you can see what language question is meant
# Out:
# 'Which <b>programming, scripting, and markup languages</b> have you done extensive development work in over the past year, and which do you want to work in over the next year? (If you both worked with the language and want to continue to do so, please check both boxes in that row.)'

# %%
schema_df.sort_index() # sorting alphabetically,# not makes changes in original, unless inplace=True
# Out:
#                        qid                                           question  \
# qname
# Accessibility       QID124  Which of the following describe you, if any? P...
# Age                 QID127                                  What is your age?
# Age1stCode          QID149  At what age did you write your first line of c...
# CompFreq             QID52   Is that compensation weekly, monthly, or yearly?
# CompTotal            QID51  What is your current total compensation (salar...
# Country               QID6  Where do you live? <span style="font-weight: b...
# Currency             QID50  Which currency do you use day-to-day? If your ...
# Database            QID262  Which <b>database environments </b>have you do...
# DevType              QID31  Which of the following describes your current ...
# EdLevel              QID25  Which of the following best describes the high...
# Employment           QID24  Which of the following best describes your cur...
# ...

# %%
schema_df.sort_index(ascending=False) # not makes changes in original, unless inplace=True
# Out:
#                        qid                                           question  \
# qname
# YearsCodePro         QID34  NOT including education, how many years have y...
# YearsCode            QID32  Including any education, how many years have y...
# Webframe            QID264  Which <strong>web frameworks </strong><span st...
# US_State              QID7  <p>In which state or territory of the USA do y...
# UK_Country            QID9  In which part of the United Kingdom do you liv...
# Trans               QID153                    Do you identify as transgender?
# ToolsTech           QID275  Which <strong>tools</strong> have you done ext...
# SurveyLength        QID132  How do you feel about the length of the survey...
# SurveyEase          QID133  How easy or difficult was this survey to compl...
# Sexuality           QID136  Which of the following describe you, if any? P...
# SOVisitFreq         QID100  How frequently would you say you visit Stack O...
# ...

# %% [markdown]
# # Filtering Data

# %%
# lets jump to our small practice dataframe
df1
# Out:
#                       email     first     last
# 0  muhammadali786@gmail.com  Muhammad      Ali
# 1     miketyson10@gmail.com      Mike    Tyson
# 2     mygmail1245@yahoo.com        Me  Podcast

# %%
filt = (df1['first'] == 'Muhammad') # filter criteria, filter is a keyword so be careful while useing

# %%
df1[filt] # using our criteria over all dataframe
# Out:
#                       email     first last
# 0  muhammadali786@gmail.com  Muhammad  Ali

# %%
df1.loc[filt] # we also can pass it in loc
# Out:
#                       email     first last
# 0  muhammadali786@gmail.com  Muhammad  Ali

# %%
df1.loc[filt, 'email'] # here you can pass columns that match with that filered data
# Out:
# 0    muhammadali786@gmail.com
# Name: email, dtype: object

# %%
# and(&), or(|) symbols cant use written and, or over data
filt1 = (df1['first'] == 'Muhammad') & (df1['last'] == 'Ali') # can use this type when data has same or duplicate data so it can choose unique data

# %%
df1.loc[filt1, 'email']
# Out:
# 0    muhammadali786@gmail.com
# Name: email, dtype: object

# %%
filt2 = (df1['first'] == 'Muhammad') | (df1['last'] == 'Podcast')
df1.loc[filt2, 'email']
# Out:
# 0    muhammadali786@gmail.com
# 2       mygmail1245@yahoo.com
# Name: email, dtype: object

# %%
df1.loc[~filt2, 'email'] # using negate of filter2
# Out:
# 1    miketyson10@gmail.com
# Name: email, dtype: object

# %% [markdown]
# # Lets jump to our Main dataframe and do some filtering

# %%
df.head()
# Out:
#    ResponseId                                         MainBranch  \
# 0           1                     I am a developer by profession
# 1           2             I am a student who is learning to code
# 2           3  I am not primarily a developer, but I write co...
# 3           4                     I am a developer by profession
# 4           5                     I am a developer by profession
#
#                                           Employment  \
# 0  Independent contractor, freelancer, or self-em...
# 1                                 Student, full-time
# 2                                 Student, full-time
# 3                                 Employed full-time
# 4  Independent contractor, freelancer, or self-em...
#
#                                              Country US_State UK_Country  \
# 0                                           Slovakia      NaN        NaN
# 1                                        Netherlands      NaN        NaN
# ...

# %%
schema_df.loc['CompTotal','question']
# Out:
# 'What is your current total compensation (salary, bonuses, and perks, before taxes and deductions), in ${q://QID50/ChoiceGroup/SelectedChoicesTextEntry}? Please enter a whole number in the box below, without any punctuation. If you are paid hourly, please estimate an equivalent weekly, monthly, or yearly salary. If you prefer not to answer, please leave the box empty.'

# %%
# so lets see the salaries of first 10 people and then apply some filtering on it
df.loc[0 : 10, ['CompTotal']]
# Out:
#     CompTotal
# 0      4800.0
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
# 5         NaN
# 6         NaN
# 7         NaN
# 8         NaN
# 9     42000.0
# 10        NaN

# %%
high_salary = (df['CompTotal'] > 50000 )

# %%
df.loc[high_salary]
# Out:
#        ResponseId                                         MainBranch  \
# 12             13                     I am a developer by profession
# 17             18                     I am a developer by profession
# 24             25                     I am a developer by profession
# 26             27  I am not primarily a developer, but I write co...
# 27             28                     I am a developer by profession
# ...           ...                                                ...
# 83432       83433                     I am a developer by profession
# 83433       83434                     I am a developer by profession
# 83434       83435                     I am a developer by profession
# 83435       83436                     I am a developer by profession
# 83437       83438                     I am a developer by profession
#
#                                               Employment  \
# 12                                    Employed full-time
# ...

# %%
df.loc[high_salary, ['Country','CompTotal','CompFreq', 'MainBranch','Age']]
# Out:
#                                                  Country  CompTotal CompFreq  \
# 12                                               Germany    71500.0   Yearly
# 17                                                Canada    61000.0   Yearly
# 24                                               Germany    72000.0   Yearly
# 26                                           Switzerland    80000.0   Yearly
# 27     United Kingdom of Great Britain and Northern I...    53000.0   Yearly
# ...                                                  ...        ...      ...
# 83432                                             Canada   106000.0   Yearly
# 83433                                             Brazil    80000.0   Yearly
# 83434                           United States of America   160500.0   Yearly
# 83435                                              Benin   200000.0  Monthly
# 83437                                             Canada    90000.0  Monthly
#
# ...

# %%
# filtering data with multiple filtering mask
countries = ['United States of America', 'Canada','Germany','India','Brazil']
filt_countries = df['Country'].isin(countries)
df.loc[filt_countries, 'Country']
# Out:
# 5        United States of America
# 6        United States of America
# 8                           India
# 12                        Germany
# 15       United States of America
#                    ...
# 83433                      Brazil
# 83434    United States of America
# 83436    United States of America
# 83437                      Canada
# 83438                      Brazil
# Name: Country, Length: 36690, dtype: object

# %%
# just checking my fellow Indian mates data :-)
df.loc[8,['CompTotal','Country','MainBranch']]
# Out:
# CompTotal                                NaN
# Country                                India
# MainBranch    I am a developer by profession
# Name: 8, dtype: object

# %%
#.str method 
filt_prog_lang = df['LanguageHaveWorkedWith'].str.contains('Python', na=False) # str.contains() method because our LanguageHaveWorkedWith column contain multiple values (or is in string mode) seprated with ;
#na = Flase for NaN values other wise it throws error
df.loc[filt_prog_lang, 'LanguageHaveWorkedWith']
# Out:
# 1                                        JavaScript;Python
# 2                                 Assembly;C;Python;R;Rust
# 4                           Bash/Shell;HTML/CSS;Python;SQL
# 5        C;C#;C++;HTML/CSS;Java;JavaScript;Node.js;Powe...
# 9                                               C++;Python
#                                ...
# 83429               HTML/CSS;PHP;PowerShell;Python;SQL;VBA
# 83430          APL;Clojure;LISP;Python;Ruby;SQL;TypeScript
# 83431    C#;Dart;HTML/CSS;Java;JavaScript;Kotlin;Node.j...
# 83436                                   Groovy;Java;Python
# 83437                 Bash/Shell;JavaScript;Node.js;Python
# Name: LanguageHaveWorkedWith, Length: 39792, dtype: object

# %%
filt_prog_lang # these filter value are true and false and when we apply it on our dataframe it works as a mask show value accordingly
# Out:
# 0        False
# 1         True
# 2         True
# 3        False
# 4         True
#          ...
# 83434    False
# 83435    False
# 83436     True
# 83437     True
# 83438    False
# Name: LanguageHaveWorkedWith, Length: 83439, dtype: bool

# %% [markdown]
# # Updating Rows and Columns

# %%
df1
# Out:
#                       email     first     last
# 0  muhammadali786@gmail.com  Muhammad      Ali
# 1     miketyson10@gmail.com      Mike    Tyson
# 2     mygmail1245@yahoo.com        Me  Podcast

# %%
df1.columns
# Out:
# Index(['email', 'first', 'last'], dtype='object')

# %%
# renaming columns
df1.columns = ['email', 'first_name','last_name'] # have to pass all columns with names

# %%
df1
# Out:
#                       email first_name last_name
# 0  muhammadali786@gmail.com   Muhammad       Ali
# 1     miketyson10@gmail.com       Mike     Tyson
# 2     mygmail1245@yahoo.com         Me   Podcast

# %% [markdown]
# # List Comprehension

# %%
df1.columns = [x.upper() for x in df1.columns] # columns name to uppercase

# %%
df1
# Out:
#                       EMAIL FIRST_NAME LAST_NAME
# 0  muhammadali786@gmail.com   Muhammad       Ali
# 1     miketyson10@gmail.com       Mike     Tyson
# 2     mygmail1245@yahoo.com         Me   Podcast

# %%
# Replacing spaces with _ in column name
df1.columns = df1.columns.str.replace(' ','_') # our practice set dont have spaces so you see nothing changes
df1
# Out:
#                       EMAIL FIRST_NAME LAST_NAME
# 0  muhammadali786@gmail.com   Muhammad       Ali
# 1     miketyson10@gmail.com       Mike     Tyson
# 2     mygmail1245@yahoo.com         Me   Podcast

# %%
df1.columns = df1.columns.str.replace('_',' ') # but if we change underscore with spaces yuoll see changes
df1
# Out:
#                       EMAIL FIRST NAME LAST NAME
# 0  muhammadali786@gmail.com   Muhammad       Ali
# 1     miketyson10@gmail.com       Mike     Tyson
# 2     mygmail1245@yahoo.com         Me   Podcast

# %%
# back to lower case
df1.columns = [x.lower() for x in df1.columns]
df1
# Out:
#                       email first name last name
# 0  muhammadali786@gmail.com   Muhammad       Ali
# 1     miketyson10@gmail.com       Mike     Tyson
# 2     mygmail1245@yahoo.com         Me   Podcast

# %%
# if we have to change specific columns
df1.rename(columns={'first name':'first', 'last name':'last'},inplace=True) #passing a dictionary with new values 
df1
# Out:
#                       email     first     last
# 0  muhammadali786@gmail.com  Muhammad      Ali
# 1     miketyson10@gmail.com      Mike    Tyson
# 2     mygmail1245@yahoo.com        Me  Podcast

# %% [markdown]
# ## Updating rows in data

# %%
df1.loc[2]
# Out:
# email    mygmail1245@yahoo.com
# first                       Me
# last                   Podcast
# Name: 2, dtype: object

# %%
# updating info in row
df1.loc[2] = ['Johnwick123@gmail.com','John','Wick'] #passing values according column wise(1=email,2=first,3=last), and have to pass all values for all column 
df1
# Out:
#                       email     first   last
# 0  muhammadali786@gmail.com  Muhammad    Ali
# 1     miketyson10@gmail.com      Mike  Tyson
# 2     Johnwick123@gmail.com      John   Wick

# %%
#using specific row value according to specific columns columns
df1.loc[2, 'email'] = 'Babayaga777@gmail.com' # in single column value we dont need a list but for multiple columns use list ex - df1.loc[2, '[email','last']] = ['Babayaga777@gmail.com','Wickey']
df1
# Out:
#                       email     first   last
# 0  muhammadali786@gmail.com  Muhammad    Ali
# 1     miketyson10@gmail.com      Mike  Tyson
# 2     Babayaga777@gmail.com      John   Wick

# %% [markdown]
# ### .at method
# can use .at instead of loc[], ex- df1.at[2, 'last'] = 'surname', it will give the same result

# %% [markdown]
# #### updating multiple rows

# %%
df1['email']=df1['email'].str.lower() # it did not channge it so you have to assign it it to real df (but in our case all our values are lower so yo didnt see anything)

# %%
df1
# Out:
#                       email     first   last
# 0  muhammadali786@gmail.com  Muhammad    Ali
# 1     miketyson10@gmail.com      Mike  Tyson
# 2     babayaga777@gmail.com      John   Wick

# %% [markdown]
# ### 4 methods to update multiple columns:
# apply<br>
# map<br>
# applymap<br>
# replace<br>

# %% [markdown]
# ### apply

# %%
df1['email'].apply(len)
# Out:
# 0    24
# 1    21
# 2    21
# Name: email, dtype: int64

# %%
def update_email(email):
    return email.upper()

# %%
df1['email'].apply(update_email)
# Out:
# 0    MUHAMMADALI786@GMAIL.COM
# 1       MIKETYSON10@GMAIL.COM
# 2       BABAYAGA777@GMAIL.COM
# Name: email, dtype: object

# %%
df1['email'] = df1['email'].apply(update_email)

# %%
df1
# Out:
#                       email     first   last
# 0  MUHAMMADALI786@GMAIL.COM  Muhammad    Ali
# 1     MIKETYSON10@GMAIL.COM      Mike  Tyson
# 2     BABAYAGA777@GMAIL.COM      John   Wick

# %%
# we can use lambda function also, lets use lambda function to convert back to lower  
df1['email'] = df1['email'].apply(lambda x: x.lower())
df1
# Out:
#                       email     first   last
# 0  muhammadali786@gmail.com  Muhammad    Ali
# 1     miketyson10@gmail.com      Mike  Tyson
# 2     babayaga777@gmail.com      John   Wick

# %%
df1.apply(len) # applying len function to each column
# Out:
# email    3
# first    3
# last     3
# dtype: int64

# %%
len(df1['email'])
# Out:
# 3

# %%
df1.apply(len, axis='columns')
# Out:
# 0    3
# 1    3
# 2    3
# dtype: int64

# %%
# grabbing minimum values 
df1.apply(pd.Series.min) # it gives according to alphabatical order with respect to first column
# Out:
# email    babayaga777@gmail.com
# first                     John
# last                       Ali
# dtype: object

# %%
df1.apply(lambda x: x.min()) # same results
# Out:
# email    babayaga777@gmail.com
# first                     John
# last                       Ali
# dtype: object

# %% [markdown]
# ### applymap
# works only on dataframe, not in series , we use it apply it on all dataframe

# %%
df1.applymap(len) # apply it on each individual value in dataframe
# Out:
#    email  first  last
# 0     24      8     3
# 1     21      4     5
# 2     21      4     4

# %%
df1.applymap(str.lower) # it dose not change unless you say so in main dataframe
# Out:
#                       email     first   last
# 0  muhammadali786@gmail.com  muhammad    ali
# 1     miketyson10@gmail.com      mike  tyson
# 2     babayaga777@gmail.com      john   wick

# %% [markdown]
# ## map

# %%
df1['first'].map({'Mike':'Baddest', 'John':'Babayaga'}) # but here is the catch the value we didnt pass gets converted to NaN and thats what we wanted in our df
# it also dosenot change in the main df directly
# Out:
# 0         NaN
# 1     Baddest
# 2    Babayaga
# Name: first, dtype: object

# %% [markdown]
# ### replace
# to overcome the unwanted NaN value problem in map we use replace

# %%
df1['first'].replace({'Mike':'Baddest', 'John':'Babayaga'})
# it also dosenot change in the main df directly
# Out:
# 0    Muhammad
# 1     Baddest
# 2    Babayaga
# Name: first, dtype: object

# %% [markdown]
# # Lests Jump to our Main df and do some Updating

# %%
df.head()
# Out:
#    ResponseId                                         MainBranch  \
# 0           1                     I am a developer by profession
# 1           2             I am a student who is learning to code
# 2           3  I am not primarily a developer, but I write co...
# 3           4                     I am a developer by profession
# 4           5                     I am a developer by profession
#
#                                           Employment  \
# 0  Independent contractor, freelancer, or self-em...
# 1                                 Student, full-time
# 2                                 Student, full-time
# 3                                 Employed full-time
# 4  Independent contractor, freelancer, or self-em...
#
#                                              Country US_State UK_Country  \
# 0                                           Slovakia      NaN        NaN
# 1                                        Netherlands      NaN        NaN
# ...

# %%
df.columns
# Out:
# Index(['ResponseId', 'MainBranch', 'Employment', 'Country', 'US_State',
#        'UK_Country', 'EdLevel', 'Age1stCode', 'LearnCode', 'YearsCode',
#        'YearsCodePro', 'DevType', 'OrgSize', 'Currency', 'CompTotal',
#        'CompFreq', 'LanguageHaveWorkedWith', 'LanguageWantToWorkWith',
#        'DatabaseHaveWorkedWith', 'DatabaseWantToWorkWith',
#        'PlatformHaveWorkedWith', 'PlatformWantToWorkWith',
#        'WebframeHaveWorkedWith', 'WebframeWantToWorkWith',
#        'MiscTechHaveWorkedWith', 'MiscTechWantToWorkWith',
#        'ToolsTechHaveWorkedWith', 'ToolsTechWantToWorkWith',
#        'NEWCollabToolsHaveWorkedWith', 'NEWCollabToolsWantToWorkWith', 'OpSys',
#        'NEWStuck', 'NEWSOSites', 'SOVisitFreq', 'SOAccount', 'SOPartFreq',
#        'SOComm', 'NEWOtherComms', 'Age', 'Gender', 'Trans', 'Sexuality',
#        'Ethnicity', 'Accessibility', 'MentalHealth', 'SurveyLength',
#        'SurveyEase', 'ConvertedCompYearly'],
#       dtype='object')

# %%
df.rename(columns={'CompTotal':'SalaryUSD'}, inplace=True) # renaming CompTotal to Salary

# %%
df['SalaryUSD']
# Out:
# 0          4800.0
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
#            ...
# 83434    160500.0
# 83435    200000.0
# 83436      1800.0
# 83437     90000.0
# 83438      7700.0
# Name: SalaryUSD, Length: 83439, dtype: float64

# %%
schema_df.loc['SOAccount','question']
# Out:
# 'Do you have a Stack Overflow account?'

# %%
df['SOAccount']
# Out:
# 0        Yes
# 1        Yes
# 2        Yes
# 3        Yes
# 4        Yes
#         ...
# 83434     No
# 83435    Yes
# 83436    Yes
# 83437    Yes
# 83438    Yes
# Name: SOAccount, Length: 83439, dtype: object

# %%
# changing yes to True and No to False but remember we are using map function so the other value might get change to NaN ( but in this case our column contain yes or no value only)
df['SOAccount'] = df['SOAccount'].map({'Yes':True, 'No':False})
df['SOAccount']
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
#          ...
# 83434    False
# 83435     True
# 83436     True
# 83437     True
# 83438     True
# Name: SOAccount, Length: 83439, dtype: object

# %% [markdown]
# # ADD/ REMOVE columns

# %%
df1
# Out:
#                       email     first   last
# 0  muhammadali786@gmail.com  Muhammad    Ali
# 1     miketyson10@gmail.com      Mike  Tyson
# 2     babayaga777@gmail.com      John   Wick

# %%
# combining columns
df1['first']+ ' ' +df1['last']
# Out:
# 0    Muhammad Ali
# 1      Mike Tyson
# 2       John Wick
# dtype: object

# %%
df1['full_name'] = df1['first']+ ' ' +df1['last']
df1
# Out:
#                       email     first   last     full_name
# 0  muhammadali786@gmail.com  Muhammad    Ali  Muhammad Ali
# 1     miketyson10@gmail.com      Mike  Tyson    Mike Tyson
# 2     babayaga777@gmail.com      John   Wick     John Wick

# %%
# removing column
df1.drop(columns=['first','last']) 
# dont change in main df unless denoted
# Out:
#                       email     full_name
# 0  muhammadali786@gmail.com  Muhammad Ali
# 1     miketyson10@gmail.com    Mike Tyson
# 2     babayaga777@gmail.com     John Wick

# %%
df1.drop(columns=['first','last'], inplace=True) # we drop those column

# %% [markdown]
# # .split()

# %%
# making a column to split between two column, split divides the value and give 
df1['full_name'].str.split(' ')
# Out:
# 0    [Muhammad, Ali]
# 1      [Mike, Tyson]
# 2       [John, Wick]
# Name: full_name, dtype: object

# %%
df1['full_name'].str.split(' ', expand=True) # expand make two different columns
# Out:
#           0      1
# 0  Muhammad    Ali
# 1      Mike  Tyson
# 2      John   Wick

# %%
# returning two columns to df
df1[['first','last']] = df1['full_name'].str.split(' ', expand=True)

# %%
df1
# Out:
#                       email     full_name     first   last
# 0  muhammadali786@gmail.com  Muhammad Ali  Muhammad    Ali
# 1     miketyson10@gmail.com    Mike Tyson      Mike  Tyson
# 2     babayaga777@gmail.com     John Wick      John   Wick

# %%
# ADDING/REMOVING ROWS
df1.append({'first':'Micheal'}, ignore_index=True)
# Out:
#                       email     full_name     first   last
# 0  muhammadali786@gmail.com  Muhammad Ali  Muhammad    Ali
# 1     miketyson10@gmail.com    Mike Tyson      Mike  Tyson
# 2     babayaga777@gmail.com     John Wick      John   Wick
# 3                       NaN           NaN   Micheal    NaN

# %% [markdown]
# # appending two dataframe

# %%
# appending TWO dataframes 

# creating second dataframe
people2 = {
    "first" : ["Jermaine","Able"], # using list in value pair bcaz we can store multiple elements
    "last" : ["Cole","Tesfaye"],
    "email" : ["jcole2014@gmail.com","theweeknd28@gmail.com"]

}

df2 = pd.DataFrame(people2)

# %%
df2
# Out:
#       first     last                  email
# 0  Jermaine     Cole    jcole2014@gmail.com
# 1      Able  Tesfaye  theweeknd28@gmail.com

# %%
# appending two dataframe
df1.append(df2, ignore_index=True)

#not changing dataframe unless denoted
# Out:
#                       email     full_name     first     last
# 0  muhammadali786@gmail.com  Muhammad Ali  Muhammad      Ali
# 1     miketyson10@gmail.com    Mike Tyson      Mike    Tyson
# 2     babayaga777@gmail.com     John Wick      John     Wick
# 3       jcole2014@gmail.com           NaN  Jermaine     Cole
# 4     theweeknd28@gmail.com           NaN      Able  Tesfaye

# %%
df1 = df1.append(df2, ignore_index=True)

# %%
df1
# Out:
#                       email     full_name     first     last
# 0  muhammadali786@gmail.com  Muhammad Ali  Muhammad      Ali
# 1     miketyson10@gmail.com    Mike Tyson      Mike    Tyson
# 2     babayaga777@gmail.com     John Wick      John     Wick
# 3       jcole2014@gmail.com           NaN  Jermaine     Cole
# 4     theweeknd28@gmail.com           NaN      Able  Tesfaye

# %%
# REMOVING ROWS
df1.drop(index=4) # use inplace = True to apply it to dataframe
# Out:
#                       email     full_name     first   last
# 0  muhammadali786@gmail.com  Muhammad Ali  Muhammad    Ali
# 1     miketyson10@gmail.com    Mike Tyson      Mike  Tyson
# 2     babayaga777@gmail.com     John Wick      John   Wick
# 3       jcole2014@gmail.com           NaN  Jermaine   Cole

# %%
df1
# Out:
#                       email     full_name     first     last
# 0  muhammadali786@gmail.com  Muhammad Ali  Muhammad      Ali
# 1     miketyson10@gmail.com    Mike Tyson      Mike    Tyson
# 2     babayaga777@gmail.com     John Wick      John     Wick
# 3       jcole2014@gmail.com           NaN  Jermaine     Cole
# 4     theweeknd28@gmail.com           NaN      Able  Tesfaye

# %%
# dropping rows using filter
filt_row = df1['last']== 'Wick'
df1.drop(index=df1[filt_row].index) # since we using index so at last use .index
# Out:
#                       email     full_name     first     last
# 0  muhammadali786@gmail.com  Muhammad Ali  Muhammad      Ali
# 1     miketyson10@gmail.com    Mike Tyson      Mike    Tyson
# 3       jcole2014@gmail.com           NaN  Jermaine     Cole
# 4     theweeknd28@gmail.com           NaN      Able  Tesfaye

# %% [markdown]
# # SORTING

# %%
df1
# Out:
#                       email     full_name     first     last
# 0  muhammadali786@gmail.com  Muhammad Ali  Muhammad      Ali
# 1     miketyson10@gmail.com    Mike Tyson      Mike    Tyson
# 2     babayaga777@gmail.com     John Wick      John     Wick
# 3       jcole2014@gmail.com           NaN  Jermaine     Cole
# 4     theweeknd28@gmail.com           NaN      Able  Tesfaye

# %%
df1.sort_values(by='last') # sorting according to last column in alpabatecial order
# Out:
#                       email     full_name     first     last
# 0  muhammadali786@gmail.com  Muhammad Ali  Muhammad      Ali
# 3       jcole2014@gmail.com           NaN  Jermaine     Cole
# 4     theweeknd28@gmail.com           NaN      Able  Tesfaye
# 1     miketyson10@gmail.com    Mike Tyson      Mike    Tyson
# 2     babayaga777@gmail.com     John Wick      John     Wick

# %%
df1.sort_values(by='last', ascending=False)
# Out:
#                       email     full_name     first     last
# 2     babayaga777@gmail.com     John Wick      John     Wick
# 1     miketyson10@gmail.com    Mike Tyson      Mike    Tyson
# 4     theweeknd28@gmail.com           NaN      Able  Tesfaye
# 3       jcole2014@gmail.com           NaN  Jermaine     Cole
# 0  muhammadali786@gmail.com  Muhammad Ali  Muhammad      Ali

# %%
# sorting with multiple columns
df1.sort_values(by=['last','first'], ascending=True)
# Out:
#                       email     full_name     first     last
# 0  muhammadali786@gmail.com  Muhammad Ali  Muhammad      Ali
# 3       jcole2014@gmail.com           NaN  Jermaine     Cole
# 4     theweeknd28@gmail.com           NaN      Able  Tesfaye
# 1     miketyson10@gmail.com    Mike Tyson      Mike    Tyson
# 2     babayaga777@gmail.com     John Wick      John     Wick

# %%
# sorting multiple columns with ascending and decending both
df1.sort_values(by=['last','first'], ascending=[True, False], inplace =True) # inplace = True to make it change in dataframe
df1
# Out:
#                       email     full_name     first     last
# 0  muhammadali786@gmail.com  Muhammad Ali  Muhammad      Ali
# 3       jcole2014@gmail.com           NaN  Jermaine     Cole
# 4     theweeknd28@gmail.com           NaN      Able  Tesfaye
# 1     miketyson10@gmail.com    Mike Tyson      Mike    Tyson
# 2     babayaga777@gmail.com     John Wick      John     Wick

# %%
# see that indexes are changed so to make them correct:
df1 = df1.sort_index()

# %%
df1
# Out:
#                       email     full_name     first     last
# 0  muhammadali786@gmail.com  Muhammad Ali  Muhammad      Ali
# 1     miketyson10@gmail.com    Mike Tyson      Mike    Tyson
# 2     babayaga777@gmail.com     John Wick      John     Wick
# 3       jcole2014@gmail.com           NaN  Jermaine     Cole
# 4     theweeknd28@gmail.com           NaN      Able  Tesfaye

# %%
df1['last'].sort_values() # sorting a single column
# Out:
# 0        Ali
# 3       Cole
# 4    Tesfaye
# 1      Tyson
# 2       Wick
# Name: last, dtype: object

# %% [markdown]
# # lets jump to main data and do some sorting

# %%
df.head()
# Out:
#    ResponseId                                         MainBranch  \
# 0           1                     I am a developer by profession
# 1           2             I am a student who is learning to code
# 2           3  I am not primarily a developer, but I write co...
# 3           4                     I am a developer by profession
# 4           5                     I am a developer by profession
#
#                                           Employment  \
# 0  Independent contractor, freelancer, or self-em...
# 1                                 Student, full-time
# 2                                 Student, full-time
# 3                                 Employed full-time
# 4  Independent contractor, freelancer, or self-em...
#
#                                              Country US_State UK_Country  \
# 0                                           Slovakia      NaN        NaN
# 1                                        Netherlands      NaN        NaN
# ...

# %%
df.sort_values(by='Country', inplace=True)

# %%
df['Country'].head(50)
# Out:
# 37431    Afghanistan
# 11461    Afghanistan
# 67130    Afghanistan
# 62970    Afghanistan
# 14882    Afghanistan
# 77979    Afghanistan
# 17120    Afghanistan
# 51791    Afghanistan
# 65205    Afghanistan
# 81479    Afghanistan
# 44640    Afghanistan
# 41840    Afghanistan
# 71691    Afghanistan
# 51428    Afghanistan
# 37765    Afghanistan
# 67508    Afghanistan
# 24552    Afghanistan
# 4544     Afghanistan
# 71921    Afghanistan
# 59268    Afghanistan
# 55624    Afghanistan
# 72965    Afghanistan
# 39471    Afghanistan
# 55150    Afghanistan
# 37549    Afghanistan
# 17486    Afghanistan
# 65399    Afghanistan
# 62832    Afghanistan
# 62786    Afghanistan
# 80371    Afghanistan
# 22666    Afghanistan
# 27198    Afghanistan
# 11131    Afghanistan
# 61674    Afghanistan
# 2069     Afghanistan
# 34427    Afghanistan
# 78757    Afghanistan
# 10945    Afghanistan
# 53203    Afghanistan
# 70794    Afghanistan
# 31086    Afghanistan
# 31504    Afghanistan
# 26034    Afghanistan
# ...

# %%
df[['Country', 'SalaryUSD']].head(50)
# Out:
#            Country  SalaryUSD
# 37431  Afghanistan        NaN
# 11461  Afghanistan        NaN
# 67130  Afghanistan        NaN
# 62970  Afghanistan        NaN
# 14882  Afghanistan     6500.0
# 77979  Afghanistan        NaN
# 17120  Afghanistan    20000.0
# 51791  Afghanistan        NaN
# 65205  Afghanistan        NaN
# 81479  Afghanistan        NaN
# 44640  Afghanistan    97333.0
# 41840  Afghanistan        NaN
# 71691  Afghanistan        NaN
# 51428  Afghanistan    30000.0
# 37765  Afghanistan        NaN
# 67508  Afghanistan        NaN
# 24552  Afghanistan        NaN
# 4544   Afghanistan        NaN
# 71921  Afghanistan        NaN
# 59268  Afghanistan        NaN
# 55624  Afghanistan        NaN
# 72965  Afghanistan        NaN
# 39471  Afghanistan        NaN
# 55150  Afghanistan        3.0
# 37549  Afghanistan        NaN
# 17486  Afghanistan    35000.0
# 65399  Afghanistan  4544242.0
# 62832  Afghanistan        NaN
# 62786  Afghanistan        NaN
# 80371  Afghanistan        NaN
# ...

# %%
# seeing highest salary by sorting salary in decending and countries in ascending
df.sort_values(by=['Country','SalaryUSD'], ascending=[True, False], inplace=True)

# %%
df[['Country', 'SalaryUSD']].head(100)
# Out:
#            Country  SalaryUSD
# 65399  Afghanistan  4544242.0
# 22666  Afghanistan  1000000.0
# 27198  Afghanistan   480000.0
# 31086  Afghanistan   154100.0
# 44640  Afghanistan    97333.0
# ...            ...        ...
# 3357       Albania     3200.0
# 15244      Albania     2000.0
# 43540      Albania     2000.0
# 14098      Albania     2000.0
# 117        Albania      400.0
#
# [100 rows x 2 columns]

# %%
# just seeing smaller or largest value from a dataset so the easy method is:
df['SalaryUSD'].nlargest(10) # top 10 highest saraly
# Out:
# 6378     1.000000e+74
# 18919    8.000000e+52
# 62417    7.000000e+39
# 103      1.000000e+29
# 23552    1.000000e+25
# 45850    6.675636e+15
# 69035    4.162026e+15
# 39571    5.474577e+10
# 82156    3.500000e+10
# 37018    1.000000e+10
# Name: SalaryUSD, dtype: float64

# %%
df.nlargest(10, 'SalaryUSD') # give 10, same rows but with all data for that particular row
# Out:
#        ResponseId                                         MainBranch  \
# 6378         6379                     I am a developer by profession
# 18919       18920                     I am a developer by profession
# 62417       62418                     I am a developer by profession
# 103           104                     I am a developer by profession
# 23552       23553  I am not primarily a developer, but I write co...
# 45850       45851                     I am a developer by profession
# 69035       69036                     I am a developer by profession
# 39571       39572                     I am a developer by profession
# 82156       82157                     I am a developer by profession
# 37018       37019                     I am a developer by profession
#
#                                               Employment  \
# 6378                                  Employed full-time
# 18919                                 Employed full-time
# ...

# %%
df['SalaryUSD'].nsmallest(10)
# Out:
# 44557    0.0
# 41280    0.0
# 77891    0.0
# 72775    0.0
# 9579     0.0
# 14457    0.0
# 12335    0.0
# 20590    0.0
# 33089    0.0
# 36918    0.0
# Name: SalaryUSD, dtype: float64

# %%
df.nsmallest(10, 'SalaryUSD')
# Out:
#        ResponseId                                         MainBranch  \
# 44557       44558                     I am a developer by profession
# 41280       41281                     I am a developer by profession
# 77891       77892                     I am a developer by profession
# 72775       72776                     I am a developer by profession
# 9579         9580  I am not primarily a developer, but I write co...
# 14457       14458                     I am a developer by profession
# 12335       12336                     I am a developer by profession
# 20590       20591                     I am a developer by profession
# 33089       33090                     I am a developer by profession
# 36918       36919                     I am a developer by profession
#
#                                               Employment     Country US_State  \
# 44557                                 Employed full-time   Argentina      NaN
# ...

# %% [markdown]
# # GROUPING AND AGGREGATING DATA

# %% [markdown]
# ### Data Analysis

# %%
df.head()
# Out:
#        ResponseId                      MainBranch  \
# 65399       65400  I am a developer by profession
# 22666       22667  I am a developer by profession
# 27198       27199  I am a developer by profession
# 31086       31087  I am a developer by profession
# 44640       44641  I am a developer by profession
#
#                                               Employment      Country  \
# 65399                                 Employed full-time  Afghanistan
# 22666  Independent contractor, freelancer, or self-em...  Afghanistan
# 27198  Independent contractor, freelancer, or self-em...  Afghanistan
# 31086                                 Employed full-time  Afghanistan
# 44640                                 Employed full-time  Afghanistan
#
#       US_State UK_Country                                          EdLevel  \
# 65399      NaN        NaN  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 22666      NaN        NaN     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# ...

# %%
df['SalaryUSD'].head(15)
# Out:
# 65399    4544242.0
# 22666    1000000.0
# 27198     480000.0
# 31086     154100.0
# 44640      97333.0
# 11377      63000.0
# 17486      35000.0
# 51428      30000.0
# 17120      20000.0
# 14882       6500.0
# 55150          3.0
# 37431          NaN
# 11461          NaN
# 67130          NaN
# 62970          NaN
# Name: SalaryUSD, dtype: float64

# %%
# lets get what is the median of salary
df['SalaryUSD'].median()
# Out:
# 67000.0

# %%
#lets run median on full dataframe and see what we get: we calculated median becz mean or average gets highly affected by outliers
df.median()
# Out:
# ResponseId             41720.0
# SalaryUSD              67000.0
# SOAccount                  1.0
# ConvertedCompYearly    56211.0
# dtype: float64

# %%
# describe gives full description about data : 50% is median so its same 
df.describe()
# count gives the non NaN values
# Out:
#          ResponseId     SalaryUSD  ConvertedCompYearly
# count  83439.000000  4.718300e+04         4.684400e+04
# mean   41720.000000  2.119407e+69         1.184262e+05
# std    24086.908893  4.603702e+71         5.272944e+05
# min        1.000000  0.000000e+00         1.000000e+00
# 25%    20860.500000  1.600000e+04         2.702500e+04
# 50%    41720.000000  6.700000e+04         5.621100e+04
# 75%    62579.500000  1.400000e+05         1.000000e+05
# max    83439.000000  1.000000e+74         4.524131e+07

# %%
df['SalaryUSD'].count()
# Out:
# 47183

# %%
# count function dont count the specific vlaues in a row, and report how many values are there in a column that what values_count do
df['Trans']
# Out:
# 65399    Yes
# 22666     No
# 27198     No
# 31086     No
# 44640     No
#         ...
# 56302     No
# 13194     No
# 80996     No
# 73741     No
# 38428     No
# Name: Trans, Length: 83439, dtype: object

# %%
# lets check how many people anewer and what answered  for the question if they are Trans or not 
df['Trans'].value_counts()
# Out:
# No                        77275
# Prefer not to say          1764
# Yes                        1035
# Or, in your own words:      604
# Name: Trans, dtype: int64

# %%
# lets see abiut what people have said about this survey
df['SurveyLength'].value_counts()
# Out:
# Appropriate in length    64514
# Too long                 13087
# Too short                 4110
# Name: SurveyLength, dtype: int64

# %%
schema_df.loc['OpSys','question']
# Out:
# 'What is the primary operating system in which you work? *'

# %%
df['OpSys'].value_counts()
# Out:
# Windows                              37758
# Linux-based                          21088
# MacOS                                20984
# Windows Subsystem for Linux (WSL)     2743
# Other (please specify):                575
# BSD                                    146
# Name: OpSys, dtype: int64

# %%
# lets break down these values to percentage by normalize
df['OpSys'].value_counts(normalize=True)
# Out:
# Windows                              0.453310
# Linux-based                          0.253175
# MacOS                                0.251927
# Windows Subsystem for Linux (WSL)    0.032932
# Other (please specify):              0.006903
# BSD                                  0.001753
# Name: OpSys, dtype: float64

# %% [markdown]
# # Grouping a data
#
#       Split   Apply Function    Combine Results

# %%
df['Country'].value_counts()
# Out:
# United States of America                                15288
# India                                                   10511
# Germany                                                  5625
# United Kingdom of Great Britain and Northern Ireland     4475
# Canada                                                   3012
#                                                         ...
# Liechtenstein                                               1
# Saint Kitts and Nevis                                       1
# Brunei Darussalam                                           1
# Tuvalu                                                      1
# Dominica                                                    1
# Name: Country, Length: 181, dtype: int64

# %%
# spliting the opject into smaller objects 
cntry_grp = df.groupby(['Country'])

# it is similar to making a filter and applying it to whole dataset but difference is it did not grab it by one country it intead splits up all responces up by country name

# %%
cntry_grp.get_group('India')
# Out:
#        ResponseId                              MainBranch  \
# 18919       18920          I am a developer by profession
# 80177       80178          I am a developer by profession
# 47843       47844          I am a developer by profession
# 70274       70275          I am a developer by profession
# 28791       28792          I am a developer by profession
# ...           ...                                     ...
# 643           644  I am a student who is learning to code
# 658           659          I am a developer by profession
# 2061         2062  I am a student who is learning to code
# 17629       17630  I am a student who is learning to code
# 633           634  I am a student who is learning to code
#
#                                    Employment Country US_State UK_Country  \
# 18919                      Employed full-time   India      NaN        NaN
# 80177                      Employed full-time   India      NaN        NaN
# ...

# %%
# its same as :
filt_OsSys = df['Country'] == 'India'
df.loc[filt_OsSys]['OpSys'].value_counts()


# lets see this with group by now
# Out:
# Windows                              5568
# Linux-based                          2554
# MacOS                                2045
# Windows Subsystem for Linux (WSL)     254
# Other (please specify):                53
# BSD                                    10
# Name: OpSys, dtype: int64

# %%
# it gives all the value count country wise with respect to column OpSys
cntry_grp['OpSys'].value_counts() # here using cntry_grp, what we created above which contain all groupby respect Country column
# Out:
# Country      OpSys
# Afghanistan  Windows                              28
#              Linux-based                          18
#              MacOS                                 6
#              Other (please specify):               6
#              BSD                                   2
#                                                   ..
# Zimbabwe     Windows                              20
#              Linux-based                           9
#              MacOS                                 5
#              Other (please specify):               1
#              Windows Subsystem for Linux (WSL)     1
# Name: OpSys, Length: 750, dtype: int64

# %%
cntry_grp['OpSys'].value_counts().head(50)
# Out:
# Country      OpSys
# Afghanistan  Windows                               28
#              Linux-based                           18
#              MacOS                                  6
#              Other (please specify):                6
#              BSD                                    2
#              Windows Subsystem for Linux (WSL)      1
# Albania      Windows                               43
#              Linux-based                           16
#              MacOS                                  7
#              Windows Subsystem for Linux (WSL)      2
#              BSD                                    1
#              Other (please specify):                1
# Algeria      Windows                               26
#              Linux-based                           13
#              MacOS                                  4
#              BSD                                    1
#              Other (please specify):                1
# ...

# %%
# now lets see results for India only
cntry_grp['OpSys'].value_counts().loc['India']
# its same as we get from when we apply filter, but we can just pass any split value and it show accordingly but in filt we have to write it for every value and apply it to whole dataset each time
# Out:
# OpSys
# Windows                              5568
# Linux-based                          2554
# MacOS                                2045
# Windows Subsystem for Linux (WSL)     254
# Other (please specify):                53
# BSD                                    10
# Name: OpSys, dtype: int64

# %%
cntry_grp['OpSys'].value_counts().loc['Angola']
# Out:
# OpSys
# Windows                              14
# Linux-based                           6
# MacOS                                 4
# Windows Subsystem for Linux (WSL)     3
# Name: OpSys, dtype: int64

# %%
# also we can see perecentage by applying normalize
cntry_grp['OpSys'].value_counts(normalize=True).loc['China']
# Out:
# OpSys
# Windows                              0.465700
# MacOS                                0.257005
# Linux-based                          0.208696
# Windows Subsystem for Linux (WSL)    0.058937
# BSD                                  0.006763
# Other (please specify):              0.002899
# Name: OpSys, dtype: float64

# %%
# median salary for all countries 
cntry_grp['SalaryUSD'].median()
# Out:
# Country
# Afghanistan                                63000.0
# Albania                                   100000.0
# Algeria                                    60000.0
# Andorra                                    87000.0
# Angola                                    130000.0
#                                            ...
# Venezuela, Bolivarian Republic of...        1000.0
# Viet Nam                                18000000.0
# Yemen                                        300.0
# Zambia                                     12000.0
# Zimbabwe                                     600.0
# Name: SalaryUSD, Length: 181, dtype: float64

# %%
cntry_grp['SalaryUSD'].median().loc['Germany']
# Out:
# 52600.0

# %%
# finding median, mean simultaneously using aggregate(agg) method 
cntry_grp['SalaryUSD'].agg(['median','mean'])
# Out:
#                                           median          mean
# Country
# Afghanistan                              63000.0  5.845616e+05
# Albania                                 100000.0  2.504897e+06
# Algeria                                  60000.0  1.791122e+05
# Andorra                                  87000.0  9.892500e+04
# Angola                                  130000.0  3.387364e+05
# ...                                          ...           ...
# Venezuela, Bolivarian Republic of...      1000.0  5.110863e+07
# Viet Nam                              18000000.0  5.330125e+07
# Yemen                                      300.0  8.436429e+04
# Zambia                                   12000.0  3.455264e+04
# Zimbabwe                                   600.0  1.135846e+03
#
# [181 rows x 2 columns]

# %%
cntry_grp['SalaryUSD'].agg(['median','mean']).loc['India']
# Out:
# median    6.220000e+05
# mean      2.052335e+49
# Name: India, dtype: float64

# %% [markdown]
# ### finding Python in Languagae worked with by grouping

# %%
# let see this by making a filter first

filt_Python_Worked_With = df['Country'] == 'India'
df.loc[filt_Python_Worked_With]['LanguageHaveWorkedWith'].str.contains('Python')
# Out:
# 18919    False
# 80177    False
# 47843     True
# 70274     True
# 28791     True
#          ...
# 643       True
# 658      False
# 2061     False
# 17629    False
# 633        NaN
# Name: LanguageHaveWorkedWith, Length: 10511, dtype: object

# %%
# .sum give the total sum, it can also work for boolean type for True=1,False=0
df.loc[filt_Python_Worked_With]['LanguageHaveWorkedWith'].str.contains('Python').sum()
# Out:
# 5233

# %%
# but remember we only make it for India so it works only for it so it gives error 
cntry_grp['LanguageHaveWorkedWith'].str.contains('Python').sum()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-177-5eb2038ead69> in <module>
#       1 # but remember we only make it for India so it works only for it so it gives error
# ----> 2 cntry_grp['LanguageHaveWorkedWith'].str.contains('Python').sum()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in __getattr__(self, attr)
#     578             return self[attr]
#     579
# --> 580         raise AttributeError(
#     581             f"'{type(self).__name__}' object has no attribute '{attr}'"
#     582         )
#
# AttributeError: 'SeriesGroupBy' object has no attribute 'str'

# %%
# using apply method  to each value for that series, to over come this
cntry_grp['LanguageHaveWorkedWith'].apply(lambda x: x.str.contains('Python').sum())

# but this gives not much of insights,like if we have to calculate the percentage so we have to know total no of people who answered and total people from tha country so its a long task
# Out:
# Country
# Afghanistan                              20
# Albania                                  30
# Algeria                                  19
# Andorra                                   4
# Angola                                    5
#                                        ...
# Venezuela, Bolivarian Republic of...     43
# Viet Nam                                173
# Yemen                                     6
# Zambia                                   12
# Zimbabwe                                 17
# Name: LanguageHaveWorkedWith, Length: 181, dtype: int64

# %% [markdown]
# #### what% of people from each country know Python?

# %%
# Lets solve this

# Total no. of people who responds this survey from each country:
country_respondents = df['Country'].value_counts()

# %%
country_respondents
# Out:
# United States of America                                15288
# India                                                   10511
# Germany                                                  5625
# United Kingdom of Great Britain and Northern Ireland     4475
# Canada                                                   3012
#                                                         ...
# Liechtenstein                                               1
# Saint Kitts and Nevis                                       1
# Brunei Darussalam                                           1
# Tuvalu                                                      1
# Dominica                                                    1
# Name: Country, Length: 181, dtype: int64

# %%
# Total no of people who have worked with python
Knows_Python = cntry_grp['LanguageHaveWorkedWith'].apply(lambda x: x.str.contains('Python').sum())
Knows_Python
# Out:
# Country
# Afghanistan                              20
# Albania                                  30
# Algeria                                  19
# Andorra                                   4
# Angola                                    5
#                                        ...
# Venezuela, Bolivarian Republic of...     43
# Viet Nam                                173
# Yemen                                     6
# Zambia                                   12
# Zimbabwe                                 17
# Name: LanguageHaveWorkedWith, Length: 181, dtype: int64

# %%
#concatinating these two series into one dataframe

python_workedwith_df = pd.concat([country_respondents, Knows_Python], axis='columns')
python_workedwith_df

# see now we can see total people from each country, telling that they worked with python or not
# Out:
#                                                     Country  \
# United States of America                              15288
# India                                                 10511
# Germany                                                5625
# United Kingdom of Great Britain and Northern Ir...     4475
# Canada                                                 3012
# ...                                                     ...
# Liechtenstein                                             1
# Saint Kitts and Nevis                                     1
# Brunei Darussalam                                         1
# Tuvalu                                                    1
# Dominica                                                  1
#
#                                                     LanguageHaveWorkedWith
# United States of America                                              7975
# India                                                                 5233
# ...

# %%
# renaming columns just for more rediability
python_workedwith_df.rename(columns={'Country':'No._Of_Respondents','LanguageHaveWorkedWith':'No._Knows_Python'}, inplace=True)

# %%
python_workedwith_df
# Out:
#                                                     No._Of_Respondents  \
# United States of America                                         15288
# India                                                            10511
# Germany                                                           5625
# United Kingdom of Great Britain and Northern Ir...                4475
# Canada                                                            3012
# ...                                                                ...
# Liechtenstein                                                        1
# Saint Kitts and Nevis                                                1
# Brunei Darussalam                                                    1
# Tuvalu                                                               1
# Dominica                                                             1
#
#                                                     No._Knows_Python
# ...

# %%
# % = selected part/ total *100
python_workedwith_df['Perc%KnowsPython'] = (python_workedwith_df['No._Knows_Python']/python_workedwith_df['No._Of_Respondents'])*100

# %%
# there we go : now we can work in that like any other dataset
python_workedwith_df
# Out:
#                                                     No._Of_Respondents  \
# United States of America                                         15288
# India                                                            10511
# Germany                                                           5625
# United Kingdom of Great Britain and Northern Ir...                4475
# Canada                                                            3012
# ...                                                                ...
# Liechtenstein                                                        1
# Saint Kitts and Nevis                                                1
# Brunei Darussalam                                                    1
# Tuvalu                                                               1
# Dominica                                                             1
#
#                                                     No._Knows_Python  \
# ...

# %%
# so lets sort these results 
python_workedwith_df.sort_values(by='Perc%KnowsPython', ascending=False) # use inplace = True to apply changes of sorting
# Out:
#                                   No._Of_Respondents  No._Knows_Python  \
# Dominica                                           1                 1
# Tuvalu                                             1                 1
# Brunei Darussalam                                  1                 1
# Liechtenstein                                      1                 1
# Sierra Leone                                       2                 2
# ...                                              ...               ...
# Mali                                               2                 0
# Papua New Guinea                                   1                 0
# Saint Vincent and the Grenadines                   1                 0
# Saint Kitts and Nevis                              1                 0
# Monaco                                             2                 0
#
#                                   Perc%KnowsPython
# Dominica                                     100.0
# ...

# %%
python_workedwith_df.sort_values(by='Perc%KnowsPython', ascending=False).head(50)
# Out:
#                                     No._Of_Respondents  No._Knows_Python  \
# Dominica                                             1                 1
# Tuvalu                                               1                 1
# Brunei Darussalam                                    1                 1
# Liechtenstein                                        1                 1
# Sierra Leone                                         2                 2
# Burundi                                              5                 4
# Burkina Faso                                         4                 3
# Namibia                                             12                 9
# Bahamas                                              7                 5
# Qatar                                               29                20
# Saint Lucia                                          3                 2
# Liberia                                              3                 2
# ...

# %%
# there you go treat it as a dataset and can perform what you want
python_workedwith_df.loc['Japan']
# Out:
# No._Of_Respondents    429.000000
# No._Knows_Python      209.000000
# Perc%KnowsPython       48.717949
# Name: Japan, dtype: float64

# %% [markdown]
# # Cleaning Data

# %%
# lets make a practice dataset
import numpy as np
people5 = {
    'first': ['Corey', 'Jane', 'John', 'Chris', np.nan, None, 'NA'], 
    'last': ['Schafer', 'Doe', 'Doe', 'Schafer', np.nan, np.nan, 'Missing'], 
    'email': ['CoreyMSchafer@gmail.com', 'JaneDoe@email.com', 'JohnDoe@email.com', None, np.nan, 'Anonymous@email.com', 'NA'],
    'age': ['33', '55', '63', '36', None, None, 'Missing']
}

# %%
df3 = pd.DataFrame(people5)

# %%
df3
# Out:
#    first     last                    email      age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com       33
# 1   Jane      Doe        JaneDoe@email.com       55
# 2   John      Doe        JohnDoe@email.com       63
# 3  Chris  Schafer                     None       36
# 4    NaN      NaN                      NaN     None
# 5   None      NaN      Anonymous@email.com     None
# 6     NA  Missing                       NA  Missing

# %%
# drops the NaN values : default dropna :df3.dropna(axis='index', how='any')
df3.dropna()
# Out:
#    first     last                    email      age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com       33
# 1   Jane      Doe        JaneDoe@email.com       55
# 2   John      Doe        JohnDoe@email.com       63
# 6     NA  Missing                       NA  Missing

# %%
df3.dropna(axis='index', how='any') # gives the same result , index wise any drops if any value is NaN
# Out:
#    first     last                    email      age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com       33
# 1   Jane      Doe        JaneDoe@email.com       55
# 2   John      Doe        JohnDoe@email.com       63
# 6     NA  Missing                       NA  Missing

# %%
df3.dropna(axis='index', how='all') # drops only those row that are fully NaN
# Out:
#    first     last                    email      age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com       33
# 1   Jane      Doe        JaneDoe@email.com       55
# 2   John      Doe        JohnDoe@email.com       63
# 3  Chris  Schafer                     None       36
# 5   None      NaN      Anonymous@email.com     None
# 6     NA  Missing                       NA  Missing

# %%
df3.dropna(axis='columns', how='all')
# Out:
#    first     last                    email      age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com       33
# 1   Jane      Doe        JaneDoe@email.com       55
# 2   John      Doe        JohnDoe@email.com       63
# 3  Chris  Schafer                     None       36
# 4    NaN      NaN                      NaN     None
# 5   None      NaN      Anonymous@email.com     None
# 6     NA  Missing                       NA  Missing

# %%
df3.dropna(axis='columns', how='any') # drops full column if it contains single NaN in it
# Out:
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2, 3, 4, 5, 6]

# %%
# droping NaN values specific to one column
df3.dropna(axis='index', how='any', subset=['email'])
# Out:
#    first     last                    email      age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com       33
# 1   Jane      Doe        JaneDoe@email.com       55
# 2   John      Doe        JohnDoe@email.com       63
# 5   None      NaN      Anonymous@email.com     None
# 6     NA  Missing                       NA  Missing

# %%
# passing multiple columns.
df3.dropna(axis='index', how='all', subset=['last','email'])
# Out:
#    first     last                    email      age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com       33
# 1   Jane      Doe        JaneDoe@email.com       55
# 2   John      Doe        JohnDoe@email.com       63
# 3  Chris  Schafer                     None       36
# 5   None      NaN      Anonymous@email.com     None
# 6     NA  Missing                       NA  Missing

# %% [markdown]
# ## custom missing value

# %%
# replacing custom values to NaN values 
df3.replace('NA',np.nan, inplace=True)
df3.replace('Missing', np.nan, inplace=True)

# %%
df3
# Out:
#    first     last                    email   age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com    33
# 1   Jane      Doe        JaneDoe@email.com    55
# 2   John      Doe        JohnDoe@email.com    63
# 3  Chris  Schafer                     None    36
# 4    NaN      NaN                      NaN  None
# 5   None      NaN      Anonymous@email.com  None
# 6    NaN      NaN                      NaN   NaN

# %%
# now we can drop them using dropna() function
df3.dropna()
# Out:
#    first     last                    email age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com  33
# 1   Jane      Doe        JaneDoe@email.com  55
# 2   John      Doe        JohnDoe@email.com  63

# %%
df3.isna()
# Out:
#    first   last  email    age
# 0  False  False  False  False
# 1  False  False  False  False
# 2  False  False  False  False
# 3  False  False   True  False
# 4   True   True   True   True
# 5   True   True  False   True
# 6   True   True   True   True

# %%
# if you dont want to drop NaN value so you can fill it with other values : it works good for numerical data
df3.fillna('MISSING') # inplace=True to make changes
# Out:
#      first     last                    email      age
# 0    Corey  Schafer  CoreyMSchafer@gmail.com       33
# 1     Jane      Doe        JaneDoe@email.com       55
# 2     John      Doe        JohnDoe@email.com       63
# 3    Chris  Schafer                  MISSING       36
# 4  MISSING  MISSING                  MISSING  MISSING
# 5  MISSING  MISSING      Anonymous@email.com  MISSING
# 6  MISSING  MISSING                  MISSING  MISSING

# %% [markdown]
# # Casting Datatypes

# %%
df3.dtypes
# Out:
# first    object
# last     object
# email    object
# age      object
# dtype: object

# %%
# see that the type of age column is object(mix of string,int etc) so you cannot apply mean method to it
df3['age'].mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-206-c7d8eea5b4e1> in <module>
#       1 # see that the type of age column is object(mix of string,int etc) so you cannot apply mean method to it
# ----> 2 df3['age'].mean()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in stat_func(self, axis, skipna, level, numeric_only, **kwargs)
#   11212         if level is not None:
#   11213             return self._agg_by_level(name, axis=axis, level=level, skipna=skipna)
# > 11214         return self._reduce(
#   11215             f, name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   11216         )
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\series.py in _reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    3889                 )
#    3890             with np.errstate(all="ignore"):
# ...

# %%
# so we covert it to number and have to use float datatype because NaN values are float type under the hood
type(np.nan)
# Out:
# float

# %%
df3['age'] = df3['age'].astype(int) # it gives error because wwe have NaN values in there
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-208-e8cfe76d48da> in <module>
# ----> 1 df3['age'] = df3['age'].astype(int) # it gives error because wwe have NaN values in there
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5696         else:
#    5697             # else, only a single dtype is given
# -> 5698             new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors)
#    5699             return self._constructor(new_data).__finalize__(self)
#    5700
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     580
#     581     def astype(self, dtype, copy: bool = False, errors: str = "raise"):
# --> 582         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     583
# ...

# %%
# so you have two choices convert that NaN to some other numeric value with fillna (thats some time a bad idea) or cast that column to float
# second method:
df3['age'] = df3['age'].astype(float) # with as type you can covert datatype into one another, if you aplly it on full dataset it can covert it for full dataset or you can apply it to a specific column like this

# %%
df3.dtypes # now age is in float
# Out:
# first     object
# last      object
# email     object
# age      float64
# dtype: object

# %%
df3['age'].mean()
# Out:
# 46.75

# %% [markdown]
# # Lest jump to main dataframe to practice

# %%
'''
we can create a variable at starting,:
na_vals = ['NA','Missing'] # we are going it to pass this string  
so at the time of reading csv we can pass it at that time and it cuts all the custom missing values at beginning 
df = pd.read_csv('data/survey_results_public.csv', index_col='Respondent', na_values=na_vals)
'''
# Out:
# "\nwe can create a variable at starting,:\nna_vals = ['NA','Missing'] # we are going it to pass this string  \nso at the time of reading csv we can pass it at that time and it cuts all the custom missing values at beginning \ndf = pd.read_csv('data/survey_results_public.csv', index_col='Respondent', na_values=na_vals)\n"

# %% [markdown]
# ### Casting the values

# %%
df.head()
# Out:
#        ResponseId                      MainBranch  \
# 65399       65400  I am a developer by profession
# 22666       22667  I am a developer by profession
# 27198       27199  I am a developer by profession
# 31086       31087  I am a developer by profession
# 44640       44641  I am a developer by profession
#
#                                               Employment      Country  \
# 65399                                 Employed full-time  Afghanistan
# 22666  Independent contractor, freelancer, or self-em...  Afghanistan
# 27198  Independent contractor, freelancer, or self-em...  Afghanistan
# 31086                                 Employed full-time  Afghanistan
# 44640                                 Employed full-time  Afghanistan
#
#       US_State UK_Country                                          EdLevel  \
# 65399      NaN        NaN  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 22666      NaN        NaN     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# ...

# %%
df['YearsCode'].head(10)
# Out:
# 65399     7
# 22666     5
# 27198     3
# 31086    16
# 44640     7
# 11377     8
# 17486     7
# 51428     7
# 17120     3
# 14882     8
# Name: YearsCode, dtype: object

# %%
df['YearsCode'].mean() # same problem
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-215-bea8a21b2b7b> in <module>
# ----> 1 df['YearsCode'].mean() # same problem
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in stat_func(self, axis, skipna, level, numeric_only, **kwargs)
#   11212         if level is not None:
#   11213             return self._agg_by_level(name, axis=axis, level=level, skipna=skipna)
# > 11214         return self._reduce(
#   11215             f, name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   11216         )
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\series.py in _reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    3889                 )
#    3890             with np.errstate(all="ignore"):
# -> 3891                 return op(delegate, skipna=skipna, **kwds)
#    3892
# ...

# %%
df['YearsCode'] = df['YearsCode'].astype(float) # it still gives error bcz it contains not only NaN values but also a string:'Less than 1 year'
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-216-71ef1b134bdd> in <module>
# ----> 1 df['YearsCode'] = df['YearsCode'].astype(float) # it still gives error bcz it contains not only NaN values but also a string:'Less than 1 year'
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5696         else:
#    5697             # else, only a single dtype is given
# -> 5698             new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors)
#    5699             return self._constructor(new_data).__finalize__(self)
#    5700
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     580
#     581     def astype(self, dtype, copy: bool = False, errors: str = "raise"):
# ...

# %%
df['YearsCode'].unique() # gives all of the unique values from that column; see we have string less than one year
# Out:
# array(['7', '5', '3', '16', '8', 'Less than 1 year', nan, '6', '2', '20',
#        '4', 'More than 50 years', '1', '10', '9', '11', '32', '23', '12',
#        '13', '25', '30', '15', '18', '14', '46', '19', '17', '36', '37',
#        '35', '26', '40', '28', '38', '31', '33', '24', '22', '34', '41',
#        '27', '21', '29', '45', '42', '48', '50', '39', '43', '47', '49',
#        '44'], dtype=object)

# %%
# so lets convert that values to numeric
df['YearsCode'].replace('Less than 1 year',0, inplace=True)

# %%
df['YearsCode'].replace('More than 50 years',51, inplace=True)

# %%
df['YearsCode'].unique() # but its type is object
# Out:
# array(['7', '5', '3', '16', '8', 0, nan, '6', '2', '20', '4', 51, '1',
#        '10', '9', '11', '32', '23', '12', '13', '25', '30', '15', '18',
#        '14', '46', '19', '17', '36', '37', '35', '26', '40', '28', '38',
#        '31', '33', '24', '22', '34', '41', '27', '21', '29', '45', '42',
#        '48', '50', '39', '43', '47', '49', '44'], dtype=object)

# %%
# lets covert that to float
df['YearsCode'] = df['YearsCode'].astype(float)

# %%
# now find avg years for that
df['YearsCode'].mean()
# Out:
# 12.338200169032717

# %%
df['YearsCode'].median()
# Out:
# 10.0

# %% [markdown]
# # Dates & Time

# %%
df4time = pd.read_csv('ETH_1h.csv')

# %%
df4time
# Out:
#                    Date  Symbol    Open    High     Low   Close      Volume
# 0      2020-03-13 08-PM  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1      2020-03-13 07-PM  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2      2020-03-13 06-PM  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3      2020-03-13 05-PM  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4      2020-03-13 04-PM  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# ...                 ...     ...     ...     ...     ...     ...         ...
# 23669  2017-07-01 03-PM  ETHUSD  265.74  272.74  265.00  272.57  1500282.55
# 23670  2017-07-01 02-PM  ETHUSD  268.79  269.90  265.00  265.74  1702536.85
# 23671  2017-07-01 01-PM  ETHUSD  274.83  274.93  265.00  268.79  3010787.99
# 23672  2017-07-01 12-PM  ETHUSD  275.01  275.01  271.00  274.83   824362.87
# 23673  2017-07-01 11-AM  ETHUSD  279.98  279.99  272.10  275.01   679358.87
#
# [23674 rows x 7 columns]

# %%
df.shape
# Out:
# (83439, 48)

# %%
df4time.loc[0,'Date']
# Out:
# '2020-03-13 08-PM'

# %%
df4time.loc[0,'Date'].day_name() # cause this is in string format
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-228-a270f05bc4a7> in <module>
# ----> 1 df4time.loc[0,'Date'].day_name() # cause this is in string format
#
# AttributeError: 'str' object has no attribute 'day_name'

# %%
# pandas can covert that automatically so we ahave to pass the format in which our date is given
df4time['Date'] = pd.to_datetime(df4time['Date'], format='%Y-%m-%d %I-%p')

# %%
df4time['Date']
# Out:
# 0       2020-03-13 20:00:00
# 1       2020-03-13 19:00:00
# 2       2020-03-13 18:00:00
# 3       2020-03-13 17:00:00
# 4       2020-03-13 16:00:00
#                 ...
# 23669   2017-07-01 15:00:00
# 23670   2017-07-01 14:00:00
# 23671   2017-07-01 13:00:00
# 23672   2017-07-01 12:00:00
# 23673   2017-07-01 11:00:00
# Name: Date, Length: 23674, dtype: datetime64[ns]

# %%
df4time.loc[0,'Date'].day_name()
# Out:
# 'Friday'

# %%
# we acan format the data at the time of reading csv:
d_parser = lambda x: pd.datetime.strptime(x, '%Y-%m-%d %I-%p') # string to time
df5datefrmted = pd.read_csv('ETH_1h.csv', parse_dates=['Date'], date_parser=d_parser)
# Out:
# <ipython-input-232-d4b4695c0847>:2: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   d_parser = lambda x: pd.datetime.strptime(x, '%Y-%m-%d %I-%p') # string to time

# %%
df5datefrmted.head() # now its loaded in datetime already
# Out:
#                  Date  Symbol    Open    High     Low   Close      Volume
# 0 2020-03-13 20:00:00  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1 2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2 2020-03-13 18:00:00  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3 2020-03-13 17:00:00  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4 2020-03-13 16:00:00  ETHUSD  124.85  129.51  120.17  124.08  4461424.71

# %%
df5datefrmted['Date'].dt.day_name() # day name for entire dataset
# Out:
# 0          Friday
# 1          Friday
# 2          Friday
# 3          Friday
# 4          Friday
#            ...
# 23669    Saturday
# 23670    Saturday
# 23671    Saturday
# 23672    Saturday
# 23673    Saturday
# Name: Date, Length: 23674, dtype: object

# %%
df5datefrmted['Date']
# Out:
# 0       2020-03-13 20:00:00
# 1       2020-03-13 19:00:00
# 2       2020-03-13 18:00:00
# 3       2020-03-13 17:00:00
# 4       2020-03-13 16:00:00
#                 ...
# 23669   2017-07-01 15:00:00
# 23670   2017-07-01 14:00:00
# 23671   2017-07-01 13:00:00
# 23672   2017-07-01 12:00:00
# 23673   2017-07-01 11:00:00
# Name: Date, Length: 23674, dtype: datetime64[ns]

# %%
df5datefrmted['DayOfWeek'] = df5datefrmted['Date'].dt.day_name()

# %%
df5datefrmted
# Out:
#                      Date  Symbol    Open    High     Low   Close      Volume  \
# 0     2020-03-13 20:00:00  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1     2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2     2020-03-13 18:00:00  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3     2020-03-13 17:00:00  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4     2020-03-13 16:00:00  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# ...                   ...     ...     ...     ...     ...     ...         ...
# 23669 2017-07-01 15:00:00  ETHUSD  265.74  272.74  265.00  272.57  1500282.55
# 23670 2017-07-01 14:00:00  ETHUSD  268.79  269.90  265.00  265.74  1702536.85
# 23671 2017-07-01 13:00:00  ETHUSD  274.83  274.93  265.00  268.79  3010787.99
# 23672 2017-07-01 12:00:00  ETHUSD  275.01  275.01  271.00  274.83   824362.87
# 23673 2017-07-01 11:00:00  ETHUSD  279.98  279.99  272.10  275.01   679358.87
#
#       DayOfWeek
# ...

# %%
# earliset date
df5datefrmted['Date'].min()
# Out:
# Timestamp('2017-07-01 11:00:00')

# %%
#most rescent date
df5datefrmted['Date'].max()
# Out:
# Timestamp('2020-03-13 20:00:00')

# %%
df5datefrmted['Date'].max() - df5datefrmted['Date'].min()
# Out:
# Timedelta('986 days 09:00:00')

# %%
# only see 2020 dates
filt = (df5datefrmted['Date'] >= pd.to_datetime('2019-01-01')) & (df5datefrmted['Date'] < pd.to_datetime('2020-01-01'))
df5datefrmted.loc[filt]
# Out:
#                      Date  Symbol    Open    High     Low   Close      Volume  \
# 1749  2019-12-31 23:00:00  ETHUSD  128.33  128.69  128.14  128.54   440678.91
# 1750  2019-12-31 22:00:00  ETHUSD  128.38  128.69  127.95  128.33   554646.02
# 1751  2019-12-31 21:00:00  ETHUSD  127.86  128.43  127.72  128.38   350155.69
# 1752  2019-12-31 20:00:00  ETHUSD  127.84  128.34  127.71  127.86   428183.38
# 1753  2019-12-31 19:00:00  ETHUSD  128.69  128.69  127.60  127.84  1169847.84
# ...                   ...     ...     ...     ...     ...     ...         ...
# 10504 2019-01-01 04:00:00  ETHUSD  130.75  133.96  130.74  131.96  2791135.37
# 10505 2019-01-01 03:00:00  ETHUSD  130.06  130.79  130.06  130.75   503732.63
# 10506 2019-01-01 02:00:00  ETHUSD  130.79  130.88  129.55  130.06   838183.43
# 10507 2019-01-01 01:00:00  ETHUSD  131.62  131.62  130.77  130.79   434917.99
# 10508 2019-01-01 00:00:00  ETHUSD  130.53  131.91  130.48  131.62  1067136.21
#
#       DayOfWeek
# ...

# %%
df5datefrmted.set_index('Date', inplace=True)

# %%
df5datefrmted
# Out:
#                      Symbol    Open    High     Low   Close      Volume  \
# Date
# 2020-03-13 20:00:00  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2020-03-13 18:00:00  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 2020-03-13 17:00:00  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 2020-03-13 16:00:00  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# ...                     ...     ...     ...     ...     ...         ...
# 2017-07-01 15:00:00  ETHUSD  265.74  272.74  265.00  272.57  1500282.55
# 2017-07-01 14:00:00  ETHUSD  268.79  269.90  265.00  265.74  1702536.85
# 2017-07-01 13:00:00  ETHUSD  274.83  274.93  265.00  268.79  3010787.99
# 2017-07-01 12:00:00  ETHUSD  275.01  275.01  271.00  274.83   824362.87
# 2017-07-01 11:00:00  ETHUSD  279.98  279.99  272.10  275.01   679358.87
#
#                     DayOfWeek
# Date
# 2020-03-13 20:00:00    Friday
# ...

# %%
# slicing using date as index
# we can use .loc also
df5datefrmted['2019']
# Out:
#                      Symbol    Open    High     Low   Close      Volume  \
# Date
# 2019-12-31 23:00:00  ETHUSD  128.33  128.69  128.14  128.54   440678.91
# 2019-12-31 22:00:00  ETHUSD  128.38  128.69  127.95  128.33   554646.02
# 2019-12-31 21:00:00  ETHUSD  127.86  128.43  127.72  128.38   350155.69
# 2019-12-31 20:00:00  ETHUSD  127.84  128.34  127.71  127.86   428183.38
# 2019-12-31 19:00:00  ETHUSD  128.69  128.69  127.60  127.84  1169847.84
# ...                     ...     ...     ...     ...     ...         ...
# 2019-01-01 04:00:00  ETHUSD  130.75  133.96  130.74  131.96  2791135.37
# 2019-01-01 03:00:00  ETHUSD  130.06  130.79  130.06  130.75   503732.63
# 2019-01-01 02:00:00  ETHUSD  130.79  130.88  129.55  130.06   838183.43
# 2019-01-01 01:00:00  ETHUSD  131.62  131.62  130.77  130.79   434917.99
# 2019-01-01 00:00:00  ETHUSD  130.53  131.91  130.48  131.62  1067136.21
#
#                     DayOfWeek
# Date
# 2019-12-31 23:00:00   Tuesday
# ...

# %%
# slcing: from jan of 2020 to feb of 2020
df5datefrmted['2020-01':'2020-02']
# Out:
#                      Symbol    Open    High     Low   Close      Volume  \
# Date
# 2020-02-29 23:00:00  ETHUSD  223.35  223.58  216.83  217.31  1927939.88
# 2020-02-29 22:00:00  ETHUSD  223.48  223.59  222.14  223.35   535998.57
# 2020-02-29 21:00:00  ETHUSD  224.63  225.14  222.74  223.48   561158.03
# 2020-02-29 20:00:00  ETHUSD  225.31  225.33  223.50  224.63   511648.65
# 2020-02-29 19:00:00  ETHUSD  225.09  225.85  223.87  225.31  1250856.20
# ...                     ...     ...     ...     ...     ...         ...
# 2020-01-01 04:00:00  ETHUSD  129.57  130.00  129.50  129.56   702786.82
# 2020-01-01 03:00:00  ETHUSD  130.37  130.44  129.38  129.57   496704.23
# 2020-01-01 02:00:00  ETHUSD  130.14  130.50  129.91  130.37   396315.72
# 2020-01-01 01:00:00  ETHUSD  128.34  130.14  128.32  130.14   635419.40
# 2020-01-01 00:00:00  ETHUSD  128.54  128.54  128.12  128.34   245119.91
#
#                      DayOfWeek
# Date
# 2020-02-29 23:00:00   Saturday
# ...

# %%
# finding average closing price of stock
# between jan to feb of 2020 (each of the days reporting by the hour)
df5datefrmted['2020-01':'2020-02']['Close']
# Out:
# Date
# 2020-02-29 23:00:00    217.31
# 2020-02-29 22:00:00    223.35
# 2020-02-29 21:00:00    223.48
# 2020-02-29 20:00:00    224.63
# 2020-02-29 19:00:00    225.31
#                         ...
# 2020-01-01 04:00:00    129.56
# 2020-01-01 03:00:00    129.57
# 2020-01-01 02:00:00    130.37
# 2020-01-01 01:00:00    130.14
# 2020-01-01 00:00:00    128.34
# Name: Close, Length: 1440, dtype: float64

# %%
# taking mean of this (on houlry basis)
df5datefrmted['2020-01':'2020-02']['Close'].mean()
# Out:
# 195.16559027777814

# %%
# what if we want to look at that in daily basis

#lets first see the high value of each hour,(first 24 value denotes a day)
df5datefrmted['2020-01':'2020-02'].head(24)
# Out:
#                      Symbol    Open    High     Low   Close      Volume  \
# Date
# 2020-02-29 23:00:00  ETHUSD  223.35  223.58  216.83  217.31  1927939.88
# 2020-02-29 22:00:00  ETHUSD  223.48  223.59  222.14  223.35   535998.57
# 2020-02-29 21:00:00  ETHUSD  224.63  225.14  222.74  223.48   561158.03
# 2020-02-29 20:00:00  ETHUSD  225.31  225.33  223.50  224.63   511648.65
# 2020-02-29 19:00:00  ETHUSD  225.09  225.85  223.87  225.31  1250856.20
# 2020-02-29 18:00:00  ETHUSD  225.53  226.17  224.50  225.09   496543.91
# 2020-02-29 17:00:00  ETHUSD  222.68  225.53  222.24  225.53   611136.47
# 2020-02-29 16:00:00  ETHUSD  224.17  225.93  222.36  222.68   694384.75
# 2020-02-29 15:00:00  ETHUSD  223.35  225.88  221.80  224.17   550893.74
# 2020-02-29 14:00:00  ETHUSD  224.42  224.42  221.15  223.35  1479928.44
# 2020-02-29 13:00:00  ETHUSD  225.29  225.37  222.87  224.42  1076646.41
# 2020-02-29 12:00:00  ETHUSD  226.50  226.50  224.14  225.29   359022.09
# ...

# %%
# now lets grab a specific day and see whats the highest of the entire day so .max()
df5datefrmted['2020-01-01']['High'].max()
# Out:
# 132.68

# %% [markdown]
# # RESAMPLING
# modifying or breaking data so it shows on the basis of day,week, month

# %%
# 'D' for days/daily, 'W for week' you can look more at google
df5datefrmted['High'].resample('D').max()
# Out:
# Date
# 2017-07-01    279.99
# 2017-07-02    293.73
# 2017-07-03    285.00
# 2017-07-04    282.83
# 2017-07-05    274.97
#                ...
# 2020-03-09    208.65
# 2020-03-10    206.28
# 2020-03-11    202.98
# 2020-03-12    195.64
# 2020-03-13    148.00
# Freq: D, Name: High, Length: 987, dtype: float64

# %%
# making it as a filter and applying it on a date to find what is the highest for that specific day
highs = df5datefrmted['High'].resample('D').max()
highs['2020-01-01']
# Out:
# 132.68

# %%
# plotting with pandas
# %matplotlib inline

# %%
highs.plot()

# %%
# what if we want to resample on the entrie dataframe
df5datefrmted.resample('W').mean() # this give the resampled value for each column on weekly basis
# Out:
#                   Open        High         Low       Close        Volume
# Date
# 2017-07-02  268.066486  271.124595  264.819730  268.202162  2.185035e+06
# 2017-07-09  261.337024  262.872917  259.186190  261.062083  1.337349e+06
# 2017-07-16  196.193214  199.204405  192.722321  195.698393  2.986756e+06
# 2017-07-23  212.351429  215.779286  209.126310  212.783750  4.298593e+06
# 2017-07-30  203.496190  205.110357  201.714048  203.309524  1.581729e+06
# ...                ...         ...         ...         ...           ...
# 2020-02-16  255.021667  257.255238  252.679762  255.198452  2.329087e+06
# 2020-02-23  265.220833  267.263690  262.948512  265.321905  1.826094e+06
# 2020-03-01  236.720536  238.697500  234.208750  236.373988  2.198762e+06
# 2020-03-08  229.923571  231.284583  228.373810  229.817619  1.628910e+06
# 2020-03-15  176.937521  179.979487  172.936239  176.332821  4.259828e+06
#
# [142 rows x 5 columns]

# %%
# but what if we  dosent want mean for certain columns like volume and we need sum of that column not mean so:
# we can pass the list and the .agg to function to perform various aggregate function on various columns
df5datefrmted.resample('W').agg({'Close': 'mean', 'High': 'max', 'Low': 'min', 'Volume': 'sum'})
# Out:
#                  Close    High     Low        Volume
# Date
# 2017-07-02  268.202162  293.73  253.23  8.084631e+07
# 2017-07-09  261.062083  285.00  231.25  2.246746e+08
# 2017-07-16  195.698393  240.33  130.26  5.017750e+08
# 2017-07-23  212.783750  249.40  153.25  7.221637e+08
# 2017-07-30  203.309524  229.99  178.03  2.657305e+08
# ...                ...     ...     ...           ...
# 2020-02-16  255.198452  290.00  216.31  3.912867e+08
# 2020-02-23  265.321905  287.13  242.36  3.067838e+08
# 2020-03-01  236.373988  278.13  209.26  3.693920e+08
# 2020-03-08  229.817619  253.01  196.00  2.736569e+08
# 2020-03-15  176.332821  208.65   90.00  4.983998e+08
#
# [142 rows x 4 columns]

# %% [markdown]
# # Reading/Writing to different file format

# %%
# we have covered how to read from csv above

# %%
#writing back to csv
filt = (df['Country'] == 'India')
india_df = df.loc[filt]
india_df.head()
# Out:
#        ResponseId                      MainBranch          Employment Country  \
# 18919       18920  I am a developer by profession  Employed full-time   India
# 80177       80178  I am a developer by profession  Employed full-time   India
# 47843       47844  I am a developer by profession  Employed full-time   India
# 70274       70275  I am a developer by profession  Employed full-time   India
# 28791       28792  I am a developer by profession  Employed full-time   India
#
#       US_State UK_Country                                       EdLevel  \
# 18919      NaN        NaN  Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 80177      NaN        NaN  Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 47843      NaN        NaN  Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 70274      NaN        NaN  Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 28791      NaN        NaN  Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
# ...

# %%
india_df.to_csv('Indiamodified.csv')

# %%
india_df.to_csv('Indiamodified2.tsv', sep='\t')

# %%
india_df.to_excel('Indiamodified3.xlsx')

# %%
readexcel = pd.read_excel('Indiamodified3.xlsx', index_col='ResponseId')

# %%
readexcel.head()
# Out:
#             Unnamed: 0                      MainBranch          Employment  \
# ResponseId
# 18920            18919  I am a developer by profession  Employed full-time
# 80178            80177  I am a developer by profession  Employed full-time
# 47844            47843  I am a developer by profession  Employed full-time
# 70275            70274  I am a developer by profession  Employed full-time
# 28792            28791  I am a developer by profession  Employed full-time
#
#            Country  US_State  UK_Country  \
# ResponseId
# 18920        India       NaN         NaN
# 80178        India       NaN         NaN
# 47844        India       NaN         NaN
# 70275        India       NaN         NaN
# 28792        India       NaN         NaN
#
#                                                  EdLevel     Age1stCode  \
# ResponseId
# 18920       Bachelor’s degree (B.A., B.S., B.Eng., etc.)  18 - 24 years
# 80178       Bachelor’s degree (B.A., B.S., B.Eng., etc.)  18 - 24 years
# ...

# %%
# to json
india_df.to_json('Indiamodified4.json', orient='records', lines=True)

# %%
readjson = pd.read_json('Indiamodified4.json', orient='records', lines=True)

# %%
readjson.head()
# Out:
#    ResponseId                      MainBranch          Employment Country  \
# 0       18920  I am a developer by profession  Employed full-time   India
# 1       80178  I am a developer by profession  Employed full-time   India
# 2       47844  I am a developer by profession  Employed full-time   India
# 3       70275  I am a developer by profession  Employed full-time   India
# 4       28792  I am a developer by profession  Employed full-time   India
#
#    US_State  UK_Country                                       EdLevel  \
# 0       NaN         NaN  Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 1       NaN         NaN  Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 2       NaN         NaN  Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 3       NaN         NaN  Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 4       NaN         NaN  Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
#       Age1stCode                                          LearnCode  \
# ...

# %% [markdown]
# # SQL

# %%
# please install by doing pip install SQLAlchemy in cmd line
from sqlalchemy import create_engine
import cx_Oracle

# %%
con = cx_Oracle.connect('PANDAS/pandas@localhost:1521/xe')
print (con.version)
# Out:
# 11.2.0.2.0

# %%
cursor = con.cursor()

# %% [markdown]
# # creating table

# %%
cursor.execute("create table employee(empid integer primary key, name varchar2(30), salary number(10, 2))")
 
print("Table Created successfully")
# Out:
# Table Created successfully

# %% [markdown]
# # inserting values

# %%
cursor.execute('insert into employee values(10001,\'Rahul\',50000.50)')
con.commit()

# %% [markdown]
# # inserting multiple values

# %%
data = [[10007, 'Vikram', 48000.0], [10008, 'Sunil', 65000.1], [10009, 'Sameer', 75000.0]]
cursor.executemany('insert into employee values(:1,:2,:3)', data)

# %% [markdown]
# # fetching data

# %%
# fetchall() is used to fetch all records from result set
cursor.execute('select * from employee')
rowsql = cursor.fetchall()
print(rowsql)
# Out:
# [(10001, 'Rahul', 50000.5), (10007, 'Vikram', 48000.0), (10008, 'Sunil', 65000.1), (10009, 'Sameer', 75000.0)]

# %%
 # fetchmany(int) is used to fetch limited number of records from result set based on integer argument passed in it
cursor.execute('select * from employee')
rowsql1 = cursor.fetchmany(3)
print(rowsql1)
# Out:
# [(10001, 'Rahul', 50000.5), (10007, 'Vikram', 48000.0), (10008, 'Sunil', 65000.1)]

# %%
# fetchone() is used fetch one record from top of the result set
cursor.execute('select * from employee')
rowsql2 = cursor.fetchone()
print(rowsql2)
# Out:
# (10001, 'Rahul', 50000.5)

# %%
'''fetchall() : The fetchall() is used to fetch all records from the result set.
fetchmany(int) : The fetchmany(int) is used to fetch the limited number of records from the result set based on the integer argument passed in it.
fetchone() : The fetchone() is used to fetch one record from the top of the result set.'''
# Out:
# 'fetchall() : The fetchall() is used to fetch all records from the result set.\nfetchmany(int) : The fetchmany(int) is used to fetch the limited number of records from the result set based on the integer argument passed in it.\nfetchone() : The fetchone() is used to fetch one record from the top of the result set.'

# %%
#View result set from a select query using bind variable.
cursor.execute('select * from employee where salary > :sal', {'sal': 50000})
rowsql3 = cursor.fetchall()
print(rowsql3)
# Out:
# [(10001, 'Rahul', 50000.5), (10008, 'Sunil', 65000.1), (10009, 'Sameer', 75000.0)]

# %% [markdown]
# # inserting dataframe in db

# %%
conn = create_engine('oracle+cx_oracle://PANDAS:pandas@localhost:1521/xe')

# %%
india_df.to_sql('TEST_df', conn, if_exists='replace')

# %%
conn.close()
