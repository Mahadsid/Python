# %%
import pandas as pd # the most powerful line :-)

# %%
df = pd.read_csv('disney_plus_titles.csv') # loading data into pandas, csv= comma seprated values
print(df)
# Out:
#      show_id     type                           title  \
# 0         s1    Movie                   A Spark Story
# 1         s2    Movie                  Spooky Buddies
# 2         s3    Movie          The Fault in Our Stars
# 3         s4  TV Show                 Dog: Impossible
# 4         s5  TV Show  Spidey And His Amazing Friends
# ...      ...      ...                             ...
# 1363   s1364    Movie          The Sword in the Stone
# 1364   s1365    Movie                 Those Calloways
# 1365   s1366  TV Show            Disney Kirby Buckets
# 1366   s1367  TV Show                  Disney Mech-X4
# 1367   s1368  TV Show              Imagination Movers
#
#                         director  \
# 0     Jason Sterman, Leanne Dare
# 1                   Robert Vince
# 2                     Josh Boone
# 3                            NaN
# 4                            NaN
# ...                          ...
# 1363         Wolfgang Reitherman
# 1364                Norman Tokar
# ...

# %%
df.head(10)
# Out:
#   show_id     type                                              title  \
# 0      s1    Movie                                      A Spark Story
# 1      s2    Movie                                     Spooky Buddies
# 2      s3    Movie                             The Fault in Our Stars
# 3      s4  TV Show                                    Dog: Impossible
# 4      s5  TV Show                     Spidey And His Amazing Friends
# 5      s6  TV Show                                 Star Wars: Visions
# 6      s7    Movie                        Confessions of a Shopaholic
# 7      s8    Movie                         Descendants: Royal Wedding
# 8      s9    Movie  Disney's Broadway Hits at London's Royal Alber...
# 9     s10    Movie                          Flooded Tombs of the Nile
#
#                      director  \
# 0  Jason Sterman, Leanne Dare
# 1                Robert Vince
# 2                  Josh Boone
# 3                         NaN
# 4                         NaN
# ...

# %%
df.tail(10)
# Out:
#      show_id     type                                     title  \
# 1358   s1359    Movie                 Justin Morgan had a Horse
# 1359   s1360    Movie  Lady and the Tramp II: Scamp's Adventure
# 1360   s1361  TV Show                                 Smart Guy
# 1361   s1362    Movie                  The Cat from Outer Space
# 1362   s1363    Movie                 The Great Mouse Detective
# 1363   s1364    Movie                    The Sword in the Stone
# 1364   s1365    Movie                           Those Calloways
# 1365   s1366  TV Show                      Disney Kirby Buckets
# 1366   s1367  TV Show                            Disney Mech-X4
# 1367   s1368  TV Show                        Imagination Movers
#
#                                       director  \
# 1358                       Hollingsworth Morse
# 1359                            Darrell Rooney
# 1360                                       NaN
# 1361                              Norman Tokar
# ...

# %%
print(df.columns)
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
# reading specific column
print(df['type'][0:5])
# Out:
# 0      Movie
# 1      Movie
# 2      Movie
# 3    TV Show
# 4    TV Show
# Name: type, dtype: object

# %%
# multiple colums
print(df[['type', 'title', 'duration']])
# Out:
#          type                           title   duration
# 0       Movie                   A Spark Story     88 min
# 1       Movie                  Spooky Buddies     93 min
# 2       Movie          The Fault in Our Stars    127 min
# 3     TV Show                 Dog: Impossible  2 Seasons
# 4     TV Show  Spidey And His Amazing Friends   1 Season
# ...       ...                             ...        ...
# 1363    Movie          The Sword in the Stone     80 min
# 1364    Movie                 Those Calloways    132 min
# 1365  TV Show            Disney Kirby Buckets  3 Seasons
# 1366  TV Show                  Disney Mech-X4  2 Seasons
# 1367  TV Show              Imagination Movers  3 Seasons
#
# [1368 rows x 3 columns]

# %%
print(df.iloc[1])
# Out:
# show_id                                                        s2
# type                                                        Movie
# title                                              Spooky Buddies
# director                                             Robert Vince
# cast            Tucker Albrizzi, Diedrich Bader, Ameko Eks Mas...
# country                                     United States, Canada
# date_added                                     September 24, 2021
# release_year                                                 2011
# rating                                                          G
# duration                                                   93 min
# listed_in                                   Comedy, Fantasy, Kids
# description     The puppies go on a spooky adventure through a...
# Name: 1, dtype: object

# %%
print(df.iloc[1:5])
# Out:
#   show_id     type                           title      director  \
# 1      s2    Movie                  Spooky Buddies  Robert Vince
# 2      s3    Movie          The Fault in Our Stars    Josh Boone
# 3      s4  TV Show                 Dog: Impossible           NaN
# 4      s5  TV Show  Spidey And His Amazing Friends           NaN
#
#                                                 cast                country  \
# 1  Tucker Albrizzi, Diedrich Bader, Ameko Eks Mas...  United States, Canada
# 2  Shailene Woodley, Ansel Elgort, Laura Dern, Sa...          United States
# 3                                       Matt Beisner          United States
# 4  Benjamin Valic, Lily Sanfelippo, Jakari Fraser...          United States
#
#            date_added  release_year rating   duration  \
# 1  September 24, 2021          2011      G     93 min
# 2  September 24, 2021          2014  PG-13    127 min
# 3  September 22, 2021          2019  TV-PG  2 Seasons
# ...

# %%
print(df.iloc[2,0])
# Out:
# s3
